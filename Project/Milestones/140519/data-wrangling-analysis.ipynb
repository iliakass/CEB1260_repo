# %% [markdown]
# # Data Wrangling & Data Cleaning (Notebook 1_Week 3 Deliverable)

# %% [markdown]
# ### Import libraries

# %%
# import the library
# %matplotlib inline

import pandas as pd #pandas library, data structures and data analysis tools for python
import numpy as np #numpy library, multi-dimensional container of generic data, and scientific use
import matplotlib.pyplot as plt #matplotlib for graphs, Python 2D plotting library

# convert scientific notation to foat "decimals"
pd.set_option('display.float_format', lambda x: '%.2f' % x)

# %% [markdown]
# ### Import the Dataset

# %%
# Source for dataset: http://donnees.ville.montreal.qc.ca/dataset/declarations-exterminations-punaises-de-lit/resource/6173de60-c2da-4d63-bc75-0607cb8dcb74
df_bedbugs = pd.read_csv('declarations-exterminations-punaises-de-lit.csv')

# %% [markdown]
# ## Summarizing data for inspection

# %% [markdown]
# #### Types

# %%
#Ref.: https://www.geeksforgeeks.org/python-pandas-series-astype-to-convert-data-type-of-series/
print(df_bedbugs.dtypes)
# Out:
# NO_DECLARATION        int64
# DATE_DECLARATION     object
# DATE_INSP_VISPRE     object
# NBR_EXTERMIN        float64
# DATE_DEBUTTRAIT      object
# DATE_FINTRAIT        object
# No_QR                object
# NOM_QR               object
# NOM_ARROND           object
# COORD_X             float64
# COORD_Y             float64
# LONGITUDE           float64
# LATITUDE            float64
# dtype: object

# %% [markdown]
# #### Converting data types

# %%
#Ref [1]: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.to_datetime.html

# Convert 'DATE_INSP_VISPRE', 'DATE_DEBUTTRAIT', and 'DATE_FINTRAIT'
df_bedbugs['DATE_INSP_VISPRE'] = pd.to_datetime(df_bedbugs['DATE_INSP_VISPRE'])
df_bedbugs['DATE_DEBUTTRAIT'] = pd.to_datetime(df_bedbugs['DATE_DEBUTTRAIT'])
df_bedbugs['DATE_FINTRAIT'] = pd.to_datetime(df_bedbugs['DATE_FINTRAIT'])

# print
print(df_bedbugs['DATE_DECLARATION'].head())
# Out:
# 0    2012-10-28T16:36:04
# 1    2011-09-16T09:45:58
# 2    2011-11-08T14:01:04
# 3    2011-08-10T09:53:47
# 4    2011-10-26T10:11:32
# Name: DATE_DECLARATION, dtype: object

# %%
# Convert 'DATE_DECLARATION to %Y-%m-%d %H:%M:%S
df_bedbugs['DATE_DECLARATION'] = pd.to_datetime(df_bedbugs['DATE_DECLARATION'])

# Ref. https://stackoverflow.com/questions/51310072/how-to-change-format-of-data-to-ymd-in-pandas
# Convert to string
df_bedbugs['DATE_DECLARATION'] = df_bedbugs['DATE_DECLARATION'].dt.strftime('%Y-%m-%d')

# Convert 'DATE_DECLARATION to %Y-%m-%d
df_bedbugs['DATE_DECLARATION'] = pd.to_datetime(df_bedbugs['DATE_DECLARATION'])

print(df_bedbugs['DATE_DECLARATION'].head())
# Out:
# 0   2012-10-28
# 1   2011-09-16
# 2   2011-11-08
# 3   2011-08-10
# 4   2011-10-26
# Name: DATE_DECLARATION, dtype: datetime64[ns]

# %%
# Print converted data types
print(df_bedbugs.dtypes)
# Out:
# NO_DECLARATION               int64
# DATE_DECLARATION    datetime64[ns]
# DATE_INSP_VISPRE    datetime64[ns]
# NBR_EXTERMIN               float64
# DATE_DEBUTTRAIT     datetime64[ns]
# DATE_FINTRAIT       datetime64[ns]
# No_QR                       object
# NOM_QR                      object
# NOM_ARROND                  object
# COORD_X                    float64
# COORD_Y                    float64
# LONGITUDE                  float64
# LATITUDE                   float64
# dtype: object

# %% [markdown]
# ### Columns, Head, and Describe Dataset

# %%
# view the dataframe index
df_bedbugs.index
# Out:
# RangeIndex(start=0, stop=33365, step=1)

# %%
# view the dataframe shape
df_bedbugs.shape
# Out:
# (33365, 13)

# %%
len(df_bedbugs)
# Out:
# 33365

# %%
print('Bed bug extermination declarations')
print('')
print('==================COLUMNS==================')
print(df_bedbugs.columns)
print('')
print('==================HEAD==================')
print(df_bedbugs.head())
print('')
print('==================DESCRIBE==================')
print(df_bedbugs.describe())
print('')
print('==================COUNT==================')
print(df_bedbugs.count())
# Out:
# Bed bug extermination declarations
#
# ==================COLUMNS==================
# Index(['NO_DECLARATION', 'DATE_DECLARATION', 'DATE_INSP_VISPRE',
#        'NBR_EXTERMIN', 'DATE_DEBUTTRAIT', 'DATE_FINTRAIT', 'No_QR', 'NOM_QR',
#        'NOM_ARROND', 'COORD_X', 'COORD_Y', 'LONGITUDE', 'LATITUDE'],
#       dtype='object')
#
# ==================HEAD==================
#    NO_DECLARATION DATE_DECLARATION DATE_INSP_VISPRE  NBR_EXTERMIN  \
# 0            4254       2012-10-28       2012-09-21          1.00
# 1             830       2011-09-16       2011-07-13          1.00
# 2            1380       2011-11-08       2011-11-02          1.00
# 3             455       2011-08-10       2011-08-09          1.00
# 4            1243       2011-10-26       2011-09-16          1.00
#
#   DATE_DEBUTTRAIT DATE_FINTRAIT No_QR         NOM_QR  \
# 0      2012-09-21    2012-09-21    24     Beaurivage
# 1      2011-07-27    2011-08-17    50    Saint-Henri
# 2      2011-11-07    2011-11-21    30   Sainte-Marie
# 3      2011-08-09    2011-08-09    44  Upper Lachine
# 4      2011-10-05    2011-10-05    19    Petite-Côte
#
#                             NOM_ARROND   COORD_X    COORD_Y  LONGITUDE  \
# 0        Mercier–Hochelaga-Maisonneuve 303753.60 5049835.70     -73.51
# 1                         Le Sud-Ouest 298119.80 5036963.70     -73.59
# 2                          Ville-Marie 300294.90 5042372.10     -73.56
# 3  Côte-des-Neiges–Notre-Dame-de-Grâce 296046.90 5036494.90     -73.61
# 4            Rosemont–La Petite-Patrie 299524.20 5045639.90     -73.57
#
#    LATITUDE
# 0     45.59
# 1     45.47
# 2     45.52
# 3     45.47
# 4     45.55
#
# ==================DESCRIBE==================
#        NO_DECLARATION  NBR_EXTERMIN   COORD_X    COORD_Y  LONGITUDE  LATITUDE
# count        33365.00      31241.00  33365.00   33365.00   33365.00  33365.00
# mean         17119.47          1.50 297055.28 5044088.86     -73.60     45.54
# std           9819.57          0.91   3664.67    4756.57       0.05      0.04
# min            104.00          1.00 274266.10 5030733.00     -73.89     45.42
# 25%           8602.00          1.00 294841.50 5041950.60     -73.63     45.52
# 50%          17099.00          1.00 297627.30 5044129.10     -73.59     45.54
# 75%          25632.00          2.00 299638.40 5046434.50     -73.57     45.56
# max          34130.00          4.00 306021.80 5062070.20     -73.48     45.70
#
# ==================COUNT==================
# NO_DECLARATION      33365
# DATE_DECLARATION    33365
# DATE_INSP_VISPRE    33357
# NBR_EXTERMIN        31241
# DATE_DEBUTTRAIT     31241
# DATE_FINTRAIT       31241
# No_QR               33365
# NOM_QR              33365
# NOM_ARROND          33365
# COORD_X             33365
# COORD_Y             33365
# LONGITUDE           33365
# LATITUDE            33365
# dtype: int64

# %% [markdown]
# #### Fixing column name

# %%
df_bedbugs.columns = ['NO_DECLARATION', 'DATE_DECLARATION', 'DATE_PRIOR_INSP', 'EXT_FREQ','DATE_FIRST_EXT','DATE_LAST_EXT',
                      'HOOD_NUM','HOOD_NAME','BORO_NAME','MTM8_X','MTM8_Y','LONGITUDE','LATITUDE']
print('==================COLUMNS==================')
print(df_bedbugs.columns)
print('')
# Out:
# ==================COLUMNS==================
# Index(['NO_DECLARATION', 'DATE_DECLARATION', 'DATE_PRIOR_INSP', 'EXT_FREQ',
#        'DATE_FIRST_EXT', 'DATE_LAST_EXT', 'HOOD_NUM', 'HOOD_NAME', 'BORO_NAME',
#        'MTM8_X', 'MTM8_Y', 'LONGITUDE', 'LATITUDE'],
#       dtype='object')

# %% [markdown]
# #### Adding new columns for intersections

# %%
#create a new column with longitude and latitude for an intersection

# Ref.: https://stackoverflow.com/questions/19377969/combine-two-columns-of-text-in-dataframe-in-pandas-python/36911306
df_bedbugs['LONG_LAT'] = df_bedbugs['LONGITUDE'].map(str)+"_"+df_bedbugs['LATITUDE'].map(str)
df_bedbugs['LONG_LAT'].head()
# Out:
# 0            -73.513411_45.588426
# 1            -73.585437_45.472569
# 2            -73.557668_45.521253
# 3            -73.611941_45.468327
# 4    -73.56756899999999_45.550652
# Name: LONG_LAT, dtype: object

# %%
# Concatenate MTM8_X and MTM8_Y
#https://stackoverflow.com/questions/42520266/concatenating-two-floats-into-one-column-in-pandas
# df['MTMXY'] = [', '.join(str(x) for x in y) for y in map(tuple, df[['MTM8_X', 'MTM8_Y']].values)]

df_bedbugs['MTM_X_Y'] = df_bedbugs['MTM8_X'].map(str)+"_"+df_bedbugs['MTM8_Y'].map(str)
df_bedbugs['MTM_X_Y'].head()
# Out:
# 0    303753.6_5049835.7
# 1    298119.8_5036963.7
# 2    300294.9_5042372.1
# 3    296046.9_5036494.9
# 4    299524.2_5045639.9
# Name: MTM_X_Y, dtype: object

# %%
df_bedbugs.shape
# Out:
# (33365, 15)

# %% [markdown]
# #### Adding new columns: declaration month, and declaration row unit

# %%
# Create a column extracting month
df_bedbugs['DEC_MONTH'] = pd.DatetimeIndex(df_bedbugs['DATE_DECLARATION']).month

# %%
# Create Declared Incidents column for regression purposes
df_bedbugs['DEC_ISSUE'] = 1

# %% [markdown]
# #### Difference between Declaration and Inspection Dates

# %%
# Ref.: https://docs.scipy.org/doc/numpy/reference/arrays.datetime.html

# Create difference between Declaration and Inspection
df_bedbugs['DATE_DIFF'] = round( (df_bedbugs['DATE_DECLARATION'] - df_bedbugs['DATE_PRIOR_INSP'] ) 
                                / np.timedelta64(1,'D') )

#df['DATE_DIFF'].fillna(0, inplace=True)

# %%
print(df_bedbugs['DATE_DIFF'].describe())
# Out:
# count   33357.00
# mean       37.33
# std        78.70
# min      -348.00
# 25%         6.00
# 50%        15.00
# 75%        39.00
# max      3737.00
# Name: DATE_DIFF, dtype: float64

# %% [markdown]
# #### Declarations at the same intersection (longitude and latitude)

# %%
print(str(len(df_bedbugs.groupby(['LONG_LAT'])))
      +' longitude and latitude group-locations')
# Out:
# 4873 longitude and latitude group-locations

# %%
#verification
((df_bedbugs.groupby(['LONG_LAT'])
       .agg({'NO_DECLARATION':'count'}))
       .sort_values(by = ['NO_DECLARATION'],ascending=False)
       .rename(columns={'NO_DECLARATION':'DECL_QT'})
       .count())
# Out:
# DECL_QT    4873
# dtype: int64

# %%
# Count of location : 1 = unique, and not equal to 1 is reoccuring
df_bedbugs.groupby(by = 'LONG_LAT')['NO_DECLARATION'].count().head()
# Out:
# LONG_LAT
# -73.484312_45.694138    1
# -73.485599_45.698515    1
# -73.487241_45.695382    6
# -73.487936_45.649078    3
# -73.489228_45.693533    1
# Name: NO_DECLARATION, dtype: int64

# %%
print('==================TOP_10_INTERSECTIONS_BASED_ON_DECLARATIONS==================')
((df_bedbugs.groupby(['LONG_LAT','HOOD_NAME','BORO_NAME'])
       .agg({'NO_DECLARATION':'count'}))
       .sort_values(by = ['NO_DECLARATION'],ascending=False)
       .rename(columns={'NO_DECLARATION':'DECL_QT'})
       .head())
# Out:
# ==================TOP_10_INTERSECTIONS_BASED_ON_DECLARATIONS==================
#                                                                                      DECL_QT
# LONG_LAT                     HOOD_NAME         BORO_NAME
# -73.571239_45.584338         Grande-Prairie    Saint-Léonard                             264
# -73.659233_45.569024         Sault-au-Récollet Ahuntsic-Cartierville                     181
# -73.620588_45.551456         Crémazie          Villeray–Saint-Michel–Parc-Extension      151
# -73.582592_45.49409          Montagne          Ville-Marie                               148
# -73.68714399999999_45.518173 Grenet            Saint-Laurent                             139

# %%
# Ref. : hhttps://stackoverflow.com/questions/12765833/counting-the-number-of-true-booleans-in-a-python-list

# Number of reoccuring locations
print(str((df_bedbugs.groupby(by = 'LONG_LAT')['NO_DECLARATION'].count()>1).sum() )
    +' longitude and latitude reoccuring group-locations')
# Out:
# 3395 longitude and latitude reoccuring group-locations

# %%
# Number of reoccuring locations, where DATE_FIRST_EXT and DATE_LAST_EXT at times co-inside
(df_bedbugs.groupby(by = 'LONG_LAT').count()>1).sum()
# Out:
# NO_DECLARATION      3395
# DATE_DECLARATION    3395
# DATE_PRIOR_INSP     3395
# EXT_FREQ            3243
# DATE_FIRST_EXT      3243
# DATE_LAST_EXT       3243
# HOOD_NUM            3395
# HOOD_NAME           3395
# BORO_NAME           3395
# MTM8_X              3395
# MTM8_Y              3395
# LONGITUDE           3395
# LATITUDE            3395
# MTM_X_Y             3395
# DEC_MONTH           3395
# DEC_ISSUE           3395
# DATE_DIFF           3395
# dtype: int64

# %%
print('Out of '+str(len(df_bedbugs))
      + ' declarations, there are '+str(len(df_bedbugs.groupby(['LONG_LAT'])))+' intersections where '
      + str((df_bedbugs.groupby(by = 'LONG_LAT')['NO_DECLARATION'].count()>1).sum() )
      + ' intersections will more than one declaration.')
print('')
print('Also, there are case for intersections with more than one declaration, where the dates of the first and last extermination are repeated.')
# Out:
# Out of 33365 declarations, there are 4873 intersections where 3395 intersections will more than one declaration.
#
# Also, there are case for intersections with more than one declaration, where the dates of the first and last extermination are repeated.

# %% [markdown]
# #### Intersections shared by boroughs and neighborhoods

# %%
# coordinates -73.587965_45.564218 show an intersection with near multi-unit building.

((df_null.groupby(['LONG_LAT','HOOD_NAME','BORO_NAME'])
       .agg({'EXT_FREQ': sum, 'NO_DECLARATION':'count'}))
       .sort_values(by = ['EXT_FREQ','NO_DECLARATION'],ascending=False)
       .rename(columns={'EXT_FREQ':'EXT_QT','NO_DECLARATION':'DECL_QT'})
       .head(5))
# Out:
#                                                                              EXT_QT  \
# LONG_LAT             HOOD_NAME         BORO_NAME
# -73.587965_45.564218 François-Perrault Villeray–Saint-Michel–Parc-Extension    0.00
# -73.575695_45.510427 Milton-Parc       Le Plateau-Mont-Royal                   0.00
# -73.581705_45.493575 Montagne          Ville-Marie                             0.00
# -73.643845_45.466798 Loyola            Côte-des-Neiges–Notre-Dame-de-Grâce     0.00
# -73.58131_45.490684  Montagne          Ville-Marie                             0.00
#
#                                                                              DECL_QT
# LONG_LAT             HOOD_NAME         BORO_NAME
# -73.587965_45.564218 François-Perrault Villeray–Saint-Michel–Parc-Extension       64
# -73.575695_45.510427 Milton-Parc       Le Plateau-Mont-Royal                      32
# -73.581705_45.493575 Montagne          Ville-Marie                                25
# -73.643845_45.466798 Loyola            Côte-des-Neiges–Notre-Dame-de-Grâce        24
# -73.58131_45.490684  Montagne          Ville-Marie                                21

# %%
((df_null[(df_null['LONG_LAT']=='-73.587965_45.564218')]
       .groupby(['LONG_LAT','HOOD_NAME','BORO_NAME'])
       .agg({'EXT_FREQ': sum, 'NO_DECLARATION':'count'}))
       .sort_values(by = ['EXT_FREQ','NO_DECLARATION'],ascending=False)
       .rename(columns={'EXT_FREQ':'EXT_QT','NO_DECLARATION':'DECL_QT'})
       .head(5))
# Out:
#                                                                                EXT_QT  \
# LONG_LAT             HOOD_NAME           BORO_NAME
# -73.587965_45.564218 François-Perrault   Villeray–Saint-Michel–Parc-Extension    0.00
#                      Étienne Desmarteaux Rosemont–La Petite-Patrie               0.00
#
#                                                                                DECL_QT
# LONG_LAT             HOOD_NAME           BORO_NAME
# -73.587965_45.564218 François-Perrault   Villeray–Saint-Michel–Parc-Extension       64
#                      Étienne Desmarteaux Rosemont–La Petite-Patrie                   1

# %%
((df_notnull[(df_notnull['LONG_LAT']=='-73.587965_45.564218')]
       .groupby(['LONG_LAT','HOOD_NAME','BORO_NAME'])
       .agg({'EXT_FREQ': sum, 'NO_DECLARATION':'count'}))
       .sort_values(by = ['EXT_FREQ','NO_DECLARATION'],ascending=False)
       .rename(columns={'EXT_FREQ':'EXT_QT','NO_DECLARATION':'DECL_QT'})
       .head(5))
# Out:
#                                                                                EXT_QT  \
# LONG_LAT             HOOD_NAME           BORO_NAME
# -73.587965_45.564218 François-Perrault   Villeray–Saint-Michel–Parc-Extension   23.00
#                      Étienne Desmarteaux Rosemont–La Petite-Patrie              12.00
#
#                                                                                DECL_QT
# LONG_LAT             HOOD_NAME           BORO_NAME
# -73.587965_45.564218 François-Perrault   Villeray–Saint-Michel–Parc-Extension       17
#                      Étienne Desmarteaux Rosemont–La Petite-Patrie                   9

# %% [markdown]
# -73.587965_45.564218 is a location intersection that falls on the border between two boroughs.

# %% [markdown]
# ###### Review of intersections

# %%
#verification
((df_bedbugs.groupby(['LONG_LAT'])
       .agg({'NO_DECLARATION':'count'}))
       .sort_values(by = ['NO_DECLARATION'],ascending=False)
       .rename(columns={'NO_DECLARATION':'DECL_QT'})
       .count())
# Out:
# DECL_QT    4873
# dtype: int64

# %%
print('==================COUNT_OF_INTERSECTIONS_INCL_BOROUGH==================')
((df_bedbugs.groupby(['LONG_LAT','BORO_NAME'])
       .agg({'NO_DECLARATION':'count'}))
       .sort_values(by = ['NO_DECLARATION'],ascending=False)
       .rename(columns={'NO_DECLARATION':'DECL_QT'})
       .count())
# Out:
# ==================COUNT_OF_INTERSECTIONS_INCL_BOROUGH==================
# DECL_QT    4921
# dtype: int64

# %%
print('==================COUNT_OF_INTERSECTIONS_INCL_NEIGHBORHOOD==================')
((df_bedbugs.groupby(['LONG_LAT','HOOD_NAME'])
       .agg({'NO_DECLARATION':'count'}))
       .sort_values(by = ['NO_DECLARATION'],ascending=False)
       .rename(columns={'NO_DECLARATION':'DECL_QT'})
       .count())
# Out:
# ==================COUNT_OF_INTERSECTIONS_INCL_NEIGHBORHOOD==================
# DECL_QT    5052
# dtype: int64

# %% [markdown]
# There is an overlap between boroughs for 48 intersections (=4921 - 4873).
# There is an overlap between neighborhoods for 179 intersections (=5052 - 4873).

# %% [markdown]
# #### Group of declarations and considering number of events

# %%
# For declarations sharing intersections, the number of summed reports where more than 4 events occured is 1755
(df_bedbugs.groupby(by = 'LONG_LAT')['EXT_FREQ'].count()>4).sum()

# %%
# Verification
df_bedbugs.groupby(by = 'LONG_LAT')['EXT_FREQ'].count().head()

# %%
# Intersection with cases of more than one report
df_bedbugs[(df_bedbugs['LONGITUDE']==-73.490471) & (df_bedbugs['LATITUDE']==45.651309000000005)]

# %% [markdown]
# ### Dealing with missing values
# How to deal with the missing values? Should we remove the rows or fill the gap with a value?

# %% [markdown]
# #### Review structure of not null dataframe

# %%
df_notnull = df_bedbugs[pd.notnull(df_bedbugs['EXT_FREQ'])]
df_notnull.describe()
# Out:
#        NO_DECLARATION  EXT_FREQ    MTM8_X     MTM8_Y  LONGITUDE  LATITUDE  \
# count        31241.00  31241.00  31241.00   31241.00   31241.00  31241.00
# mean         17061.36      1.50 297102.04 5044105.27     -73.60     45.54
# std           9822.28      0.91   3671.99    4772.25       0.05      0.04
# min            104.00      1.00 274266.10 5030733.00     -73.89     45.42
# 25%           8563.00      1.00 294890.30 5041950.60     -73.63     45.52
# 50%          17028.00      1.00 297706.60 5044179.10     -73.59     45.54
# 75%          25555.00      2.00 299678.30 5046440.50     -73.57     45.56
# max          34130.00      4.00 305921.50 5062070.20     -73.49     45.70
#
#        DEC_MONTH  DEC_ISSUE  DATE_DIFF
# count   31241.00   31241.00   31241.00
# mean        7.13       1.00      36.79
# std         3.34       0.00      78.21
# min         1.00       1.00    -348.00
# 25%         4.00       1.00       6.00
# 50%         8.00       1.00      15.00
# 75%        10.00       1.00      39.00
# max        12.00       1.00    3737.00

# %%
# Review lead time between the declaration dates and prior inspection date, for null values
(df_notnull['DATE_DECLARATION'] - df_notnull['DATE_PRIOR_INSP']).describe()
# Out:
# count                      31241
# mean     36 days 19:03:01.261803
# std      78 days 05:02:23.472064
# min          -348 days +00:00:00
# 25%              6 days 00:00:00
# 50%             15 days 00:00:00
# 75%             39 days 00:00:00
# max           3737 days 00:00:00
# dtype: object

# %% [markdown]
# #### Identify count of missing values

# %%
print('==================TYPES==================')
print(df_bedbugs.dtypes)
print('')
print('==================NULL_VALUES==================')
# Check for null values
print(df_bedbugs.isnull().sum())
# Out:
# ==================TYPES==================
# NO_DECLARATION               int64
# DATE_DECLARATION    datetime64[ns]
# DATE_PRIOR_INSP     datetime64[ns]
# EXT_FREQ                   float64
# DATE_FIRST_EXT      datetime64[ns]
# DATE_LAST_EXT       datetime64[ns]
# HOOD_NUM                    object
# HOOD_NAME                   object
# BORO_NAME                   object
# MTM8_X                     float64
# MTM8_Y                     float64
# LONGITUDE                  float64
# LATITUDE                   float64
# LONG_LAT                    object
# MTM_X_Y                     object
# DEC_MONTH                    int64
# DEC_ISSUE                    int64
# DATE_DIFF                  float64
# dtype: object
#
# ==================NULL_VALUES==================
# NO_DECLARATION         0
# DATE_DECLARATION       0
# DATE_PRIOR_INSP        8
# EXT_FREQ            2124
# DATE_FIRST_EXT      2124
# DATE_LAST_EXT       2124
# HOOD_NUM               0
# HOOD_NAME              0
# BORO_NAME              0
# MTM8_X                 0
# MTM8_Y                 0
# LONGITUDE              0
# LATITUDE               0
# LONG_LAT               0
# MTM_X_Y                0
# DEC_MONTH              0
# DEC_ISSUE              0
# DATE_DIFF              8
# dtype: int64

# %% [markdown]
# #### Analyse Null dataframe

# %%
# Populate blank values in EXT_FREQ 
df_null = df_bedbugs[pd.isnull(df_bedbugs['EXT_FREQ'])]
df_null.describe()
# Out:
#        NO_DECLARATION  EXT_FREQ    MTM8_X     MTM8_Y  LONGITUDE  LATITUDE  \
# count         2124.00      0.00   2124.00    2124.00    2124.00   2124.00
# mean         17974.31       nan 296367.48 5043847.46     -73.61     45.53
# std           9741.99       nan   3484.39    4513.88       0.04      0.04
# min            356.00       nan 275320.30 5030909.00     -73.88     45.42
# 25%           9083.50       nan 294450.40 5041870.00     -73.63     45.52
# 50%          18132.00       nan 295991.40 5043601.20     -73.61     45.53
# 75%          26906.25       nan 298803.00 5046221.33     -73.58     45.56
# max          34114.00       nan 306021.80 5061583.80     -73.48     45.69
#
#        DEC_MONTH  DEC_ISSUE  DATE_DIFF
# count    2124.00    2124.00    2116.00
# mean        7.26       1.00      45.19
# std         3.12       0.00      85.30
# min         1.00       1.00     -27.00
# 25%         5.00       1.00       3.00
# 50%         7.00       1.00      17.00
# 75%        10.00       1.00      45.00
# max        12.00       1.00    1165.00

# %%
df_null
# Out:
#        NO_DECLARATION DATE_DECLARATION DATE_PRIOR_INSP  EXT_FREQ  \
# 5                4331       2012-11-08      2012-10-10       nan
# 25               3117       2012-07-09      2012-06-01       nan
# 39               2202       2012-02-19      2011-11-02       nan
# 41               1896       2011-12-22      2011-12-22       nan
# 45               3367       2012-07-27      2012-07-16       nan
# 111              7054       2013-06-12      2013-04-12       nan
# 137              7412       2013-06-26      2013-06-17       nan
# 167             10943       2014-02-03      2013-11-21       nan
# 184             10069       2013-11-28      2013-10-15       nan
# 189             11591       2014-03-22      2014-03-12       nan
# 230             14782       2014-11-04      2014-11-04       nan
# 235             17499       2015-06-09      2015-05-15       nan
# 249             15882       2015-01-20      2014-10-17       nan
# 285             20372       2015-11-17      2015-11-14       nan
# 301             21178       2016-01-11      2015-11-16       nan
# 307             19403       2015-10-10      2015-09-30       nan
# 336             27680       2017-07-07      2017-06-15       nan
# 337             27685       2017-07-07      2017-06-15       nan
# 370             26129       2017-02-21      2017-02-14       nan
# 396             25448       2016-12-09      2016-08-31       nan
# 406             27601       2017-07-07      2017-06-07       nan
# 410             28352       2017-08-31      2016-10-27       nan
# 416             32174       2018-08-03      2018-06-13       nan
# 418             28525       2017-09-07      2016-10-07       nan
# 439             28703       2017-09-09      2016-10-04       nan
# 457             29287       2017-10-18      2017-10-17       nan
# 469             32057       2018-07-31      2018-07-26       nan
# 479             34108       2018-12-25      2018-11-03       nan
# 481             33875       2018-12-04      2018-08-24       nan
# 488             32677       2018-09-12      2018-09-11       nan
# ...               ...              ...             ...       ...
# 32997           10067       2013-11-28      2013-10-09       nan
# 33001           13067       2014-08-01      2014-07-01       nan
# 33004           16672       2015-03-30      2015-03-24       nan
# 33014            2547       2012-04-16      2012-01-16       nan
# 33018            4784       2013-01-08      2012-08-14       nan
# 33021            6188       2013-04-11      2013-04-09       nan
# 33034           16311       2015-02-19      2015-02-12       nan
# 33057           27637       2017-07-07      2017-06-12       nan
# 33061           33982       2018-12-12      2018-11-09       nan
# 33076           11224       2014-02-20      2014-02-10       nan
# 33083           26797       2017-05-09      2017-05-02       nan
# 33122           16678       2015-03-30      2015-03-12       nan
# 33123           23165       2016-07-05      2016-05-24       nan
# 33127           31011       2018-04-12      2018-04-12       nan
# 33182           30944       2018-04-07      2018-03-05       nan
# 33187             714       2011-09-02      2011-09-02       nan
# 33227           21659       2016-02-27      2016-02-15       nan
# 33249           23758       2016-08-17      2016-02-29       nan
# 33269           22286       2016-04-13      2016-04-01       nan
# 33273           27734       2017-07-12      2017-06-21       nan
# 33281            4374       2012-11-16      2012-11-16       nan
# 33286           17476       2015-06-08      2015-06-02       nan
# 33288           17908       2015-07-09      2015-07-15       nan
# 33294           23808       2016-08-19      2016-08-05       nan
# 33303            6146       2013-04-08      2013-03-09       nan
# 33305           10074       2013-11-28      2013-11-11       nan
# 33309           14156       2014-10-07      2014-10-05       nan
# 33311           16873       2015-04-17      2015-04-15       nan
# 33331           29152       2017-10-05      2017-10-05       nan
# 33343            8559       2013-09-19      2013-09-14       nan
#
#       DATE_FIRST_EXT DATE_LAST_EXT HOOD_NUM                     HOOD_NAME  \
# 5                NaT           NaT       20                Marie-Victorin
# 25               NaT           NaT       70  Vieux-Lachine - Saint-Pierre
# 39               NaT           NaT       39                      Montagne
# 41               NaT           NaT       11                Parc-Extension
# 45               NaT           NaT       26                 Longue-Pointe
# 111              NaT           NaT       14                 Saint-Édouard
# 137              NaT           NaT       45                        Loyola
# 167              NaT           NaT       11                Parc-Extension
# 184              NaT           NaT       30                  Sainte-Marie
# 189              NaT           NaT       20                Marie-Victorin
# 230              NaT           NaT       12                    Parc-Jarry
# 235              NaT           NaT       13                      Crémazie
# 249              NaT           NaT       64                 Verdun-Centre
# 285              NaT           NaT       43                        Savane
# 301              NaT           NaT       42                     Parc-Kent
# 307              NaT           NaT       05                 Saint-Sulpice
# 336              NaT           NaT       12                    Parc-Jarry
# 337              NaT           NaT       11                Parc-Extension
# 370              NaT           NaT       42                     Parc-Kent
# 396              NaT           NaT       17           Étienne Desmarteaux
# 406              NaT           NaT       11                Parc-Extension
# 410              NaT           NaT       63                Grande-Prairie
# 416              NaT           NaT       35                   Saint-Louis
# 418              NaT           NaT       13                      Crémazie
# 439              NaT           NaT       18                Vieux-Rosemont
# 457              NaT           NaT       09                Gabriel-Sagard
# 469              NaT           NaT       06                 La Visitation
# 479              NaT           NaT       28                   Maisonneuve
# 481              NaT           NaT       18                Vieux-Rosemont
# 488              NaT           NaT      60B                   Centre-Nord
# ...              ...           ...      ...                           ...
# 32997            NaT           NaT       37                Vieux-Montréal
# 33001            NaT           NaT       36                   Milton-Parc
# 33004            NaT           NaT       36                   Milton-Parc
# 33014            NaT           NaT       36                   Milton-Parc
# 33018            NaT           NaT       62                  Port-Maurice
# 33021            NaT           NaT       50                   Saint-Henri
# 33034            NaT           NaT       36                   Milton-Parc
# 33057            NaT           NaT       61                           Est
# 33061            NaT           NaT       52            Marc-Aurèle-Fortin
# 33076            NaT           NaT       13                      Crémazie
# 33083            NaT           NaT       18                Vieux-Rosemont
# 33122            NaT           NaT       36                   Milton-Parc
# 33123            NaT           NaT       11                Parc-Extension
# 33127            NaT           NaT       74                     Outremont
# 33182            NaT           NaT       09                Gabriel-Sagard
# 33187            NaT           NaT       51              Petite-Bourgogne
# 33227            NaT           NaT       11                Parc-Extension
# 33249            NaT           NaT       54           Pointe-aux-Trembles
# 33269            NaT           NaT       02              Nouveau-Bordeaux
# 33273            NaT           NaT       28                   Maisonneuve
# 33281            NaT           NaT       59              Du College/Hodge
# 33286            NaT           NaT       67               Cecil-P.-Newman
# 33288            NaT           NaT       30                  Sainte-Marie
# 33294            NaT           NaT       17           Étienne Desmarteaux
# 33303            NaT           NaT       22                        Dupéré
# 33305            NaT           NaT       26                 Longue-Pointe
# 33309            NaT           NaT       44                 Upper Lachine
# 33311            NaT           NaT       02              Nouveau-Bordeaux
# 33331            NaT           NaT       50                   Saint-Henri
# 33343            NaT           NaT       36                   Milton-Parc
#
#                                       BORO_NAME    MTM8_X     MTM8_Y  \
# 5                     Rosemont–La Petite-Patrie 298622.20 5047041.40
# 25                                      Lachine 291759.20 5033576.50
# 39                                  Ville-Marie 298505.60 5039407.60
# 41         Villeray–Saint-Michel–Parc-Extension 294566.70 5043001.20
# 45                Mercier–Hochelaga-Maisonneuve 301819.90 5048615.20
# 111                   Rosemont–La Petite-Patrie 296124.70 5043220.90
# 137         Côte-des-Neiges–Notre-Dame-de-Grâce 293551.90 5036329.00
# 167        Villeray–Saint-Michel–Parc-Extension 294815.80 5042767.20
# 184                                 Ville-Marie 300179.30 5043509.90
# 189                   Rosemont–La Petite-Patrie 298529.90 5048250.50
# 230        Villeray–Saint-Michel–Parc-Extension 295409.10 5044461.30
# 235        Villeray–Saint-Michel–Parc-Extension 294830.70 5045002.20
# 249                                      Verdun 298843.70 5035305.00
# 285         Côte-des-Neiges–Notre-Dame-de-Grâce 294265.10 5039251.60
# 301         Côte-des-Neiges–Notre-Dame-de-Grâce 295251.50 5041377.80
# 307                       Ahuntsic-Cartierville 293473.90 5045408.00
# 336        Villeray–Saint-Michel–Parc-Extension 294678.60 5044669.80
# 337        Villeray–Saint-Michel–Parc-Extension 293722.40 5043701.60
# 370         Côte-des-Neiges–Notre-Dame-de-Grâce 294281.00 5040782.60
# 396                   Rosemont–La Petite-Patrie 298185.90 5046939.80
# 406        Villeray–Saint-Michel–Parc-Extension 295044.40 5043311.10
# 410                               Saint-Léonard 297104.50 5051523.70
# 416                       Le Plateau-Mont-Royal 299085.30 5041939.10
# 418        Villeray–Saint-Michel–Parc-Extension 295648.50 5045400.10
# 439                   Rosemont–La Petite-Patrie 299208.70 5046597.10
# 457        Villeray–Saint-Michel–Parc-Extension 295837.90 5046357.00
# 469                       Ahuntsic-Cartierville 293016.20 5048473.60
# 479               Mercier–Hochelaga-Maisonneuve 302085.00 5046275.60
# 481                   Rosemont–La Petite-Patrie 298515.60 5045014.50
# 488                               Montréal-Nord 295330.40 5051818.10
# ...                                         ...       ...        ...
# 32997                               Ville-Marie 299933.00 5039639.10
# 33001                     Le Plateau-Mont-Royal 298885.50 5041170.30
# 33004                     Le Plateau-Mont-Royal 298885.50 5041170.30
# 33014                     Le Plateau-Mont-Royal 299095.10 5041146.10
# 33018                             Saint-Léonard 296445.30 5049181.50
# 33021                              Le Sud-Ouest 298499.60 5037508.00
# 33034                     Le Plateau-Mont-Royal 299095.10 5041146.10
# 33057                             Montréal-Nord 295021.10 5053817.10
# 33061  Rivière-des-Prairies–Pointe-aux-Trembles 295736.10 5054456.20
# 33076      Villeray–Saint-Michel–Parc-Extension 295854.90 5045713.10
# 33083                 Rosemont–La Petite-Patrie 299499.30 5045581.10
# 33122                     Le Plateau-Mont-Royal 299095.10 5041146.10
# 33123      Villeray–Saint-Michel–Parc-Extension 293838.20 5043304.40
# 33127                                 Outremont 296054.00 5042655.30
# 33182      Villeray–Saint-Michel–Parc-Extension 295811.60 5045920.10
# 33187                              Le Sud-Ouest 300034.50 5039630.10
# 33227      Villeray–Saint-Michel–Parc-Extension 294938.20 5043058.10
# 33249  Rivière-des-Prairies–Pointe-aux-Trembles 305332.00 5057869.10
# 33269                     Ahuntsic-Cartierville 291058.50 5044150.50
# 33273             Mercier–Hochelaga-Maisonneuve 301815.70 5046113.60
# 33281                             Saint-Laurent 291021.50 5040468.50
# 33286                                   LaSalle 293915.10 5031396.90
# 33288                               Ville-Marie 300466.90 5042151.10
# 33294                 Rosemont–La Petite-Patrie 298578.80 5046967.20
# 33303             Mercier–Hochelaga-Maisonneuve 302243.70 5051151.90
# 33305             Mercier–Hochelaga-Maisonneuve 302147.60 5049787.40
# 33309       Côte-des-Neiges–Notre-Dame-de-Grâce 295302.40 5036070.10
# 33311                     Ahuntsic-Cartierville 288512.00 5044500.50
# 33331                              Le Sud-Ouest 298435.20 5038087.90
# 33343                     Le Plateau-Mont-Royal 298885.50 5041170.30
#
#        LONGITUDE  LATITUDE                               LONG_LAT  \
# 5         -73.58     45.56                   -73.579138_45.563256
# 25        -73.67     45.44          -73.666698_45.441998999999996
# 39        -73.58     45.49                   -73.580535_45.494563
# 41        -73.63     45.53                   -73.631007_45.526853
# 45        -73.54     45.58                   -73.538186_45.577438
# 111       -73.61     45.53                   -73.611065_45.528851
# 137       -73.64     45.47                   -73.643845_45.466798
# 167       -73.63     45.52                   -73.627812_45.524751
# 184       -73.56     45.53          -73.559159_45.531490999999995
# 189       -73.58     45.57                   -73.580336_45.574135
# 230       -73.62     45.54           -73.62025_45.540003999999996
# 235       -73.63     45.54                   -73.627668_45.544862
# 249       -73.58     45.46  -73.57615899999999_45.457648999999996
# 285       -73.63     45.49                   -73.634787_45.493108
# 301       -73.62     45.51  -73.62220699999999_45.512254999999996
# 307       -73.65     45.55                   -73.645052_45.548493
# 336       -73.63     45.54           -73.62960799999999_45.541869
# 337       -73.64     45.53           -73.64183100000001_45.533142
# 370       -73.63     45.51                   -73.634617_45.506885
# 396       -73.58     45.56                   -73.584727_45.562337
# 406       -73.62     45.53                   -73.624897_45.529648
# 410       -73.60     45.60                   -73.598651_45.603574
# 416       -73.57     45.52  -73.57314699999999_45.517346999999994
# 418       -73.62     45.55                   -73.617202_45.548454
# 439       -73.57     45.56                   -73.571621_45.559263
# 457       -73.61     45.56  -73.61479399999999_45.557066999999996
# 469       -73.65     45.58                   -73.650987_45.576071
# 479       -73.53     45.56           -73.53477600000001_45.556387
# 481       -73.58     45.55                   -73.580479_45.545016
# 488       -73.62     45.61                     -73.6214_45.606201
# ...          ...       ...                                    ...
# 32997     -73.56     45.50          -73.562274_45.496658000000004
# 33001     -73.58     45.51                   -73.575695_45.510427
# 33004     -73.58     45.51                   -73.575695_45.510427
# 33014     -73.57     45.51                   -73.573012_45.510212
# 33018     -73.61     45.58                    -73.607061_45.58249
# 33021     -73.58     45.48          -73.580587_45.477470000000004
# 33034     -73.57     45.51                   -73.573012_45.510212
# 33057     -73.63     45.62           -73.62540600000001_45.624184
# 33061     -73.62     45.63                   -73.616249_45.629945
# 33076     -73.61     45.55                   -73.614564_45.551274
# 33083     -73.57     45.55                   -73.567887_45.550123
# 33122     -73.57     45.51                   -73.573012_45.510212
# 33123     -73.64     45.53            -73.64034000000001_45.52957
# 33127     -73.61     45.52           -73.61196_45.523759999999996
# 33182     -73.62     45.55                   -73.615123_45.553135
# 33187     -73.56     45.50                   -73.560974_45.496577
# 33227     -73.63     45.53                    -73.626251_45.52737
# 33249     -73.49     45.66                   -73.493173_45.660714
# 33269     -73.68     45.54                    -73.67595_45.537134
# 33273     -73.54     45.55          -73.538224_45.554928000000004
# 33281     -73.68     45.50                   -73.676321_45.504002
# 33286     -73.64     45.42           -73.63909_45.422422999999995
# 33288     -73.56     45.52          -73.555465_45.519265000000004
# 33294     -73.58     45.56                   -73.579693_45.562588
# 33303     -73.53     45.60                   -73.532768_45.600266
# 33305     -73.53     45.59           -73.53399300000001_45.587987
# 33309     -73.62     45.46                   -73.621454_45.464495
# 33311     -73.71     45.54                   -73.708568_45.540229
# 33331     -73.58     45.48                   -73.581418_45.482687
# 33343     -73.58     45.51                   -73.575695_45.510427
#
#                   MTM_X_Y  DEC_MONTH  DEC_ISSUE  DATE_DIFF
# 5      298622.2_5047041.4         11          1      29.00
# 25     291759.2_5033576.5          7          1      38.00
# 39     298505.6_5039407.6          2          1     109.00
# 41     294566.7_5043001.2         12          1       0.00
# 45     301819.9_5048615.2          7          1      11.00
# 111    296124.7_5043220.9          6          1      61.00
# 137    293551.9_5036329.0          6          1       9.00
# 167    294815.8_5042767.2          2          1      74.00
# 184    300179.3_5043509.9         11          1      44.00
# 189    298529.9_5048250.5          3          1      10.00
# 230    295409.1_5044461.3         11          1       0.00
# 235    294830.7_5045002.2          6          1      25.00
# 249    298843.7_5035305.0          1          1      95.00
# 285    294265.1_5039251.6         11          1       3.00
# 301    295251.5_5041377.8          1          1      56.00
# 307    293473.9_5045408.0         10          1      10.00
# 336    294678.6_5044669.8          7          1      22.00
# 337    293722.4_5043701.6          7          1      22.00
# 370    294281.0_5040782.6          2          1       7.00
# 396    298185.9_5046939.8         12          1     100.00
# 406    295044.4_5043311.1          7          1      30.00
# 410    297104.5_5051523.7          8          1     308.00
# 416    299085.3_5041939.1          8          1      51.00
# 418    295648.5_5045400.1          9          1     335.00
# 439    299208.7_5046597.1          9          1     340.00
# 457    295837.9_5046357.0         10          1       1.00
# 469    293016.2_5048473.6          7          1       5.00
# 479    302085.0_5046275.6         12          1      52.00
# 481    298515.6_5045014.5         12          1     102.00
# 488    295330.4_5051818.1          9          1       1.00
# ...                   ...        ...        ...        ...
# 32997  299933.0_5039639.1         11          1      50.00
# 33001  298885.5_5041170.3          8          1      31.00
# 33004  298885.5_5041170.3          3          1       6.00
# 33014  299095.1_5041146.1          4          1      91.00
# 33018  296445.3_5049181.5          1          1     147.00
# 33021  298499.6_5037508.0          4          1       2.00
# 33034  299095.1_5041146.1          2          1       7.00
# 33057  295021.1_5053817.1          7          1      25.00
# 33061  295736.1_5054456.2         12          1      33.00
# 33076  295854.9_5045713.1          2          1      10.00
# 33083  299499.3_5045581.1          5          1       7.00
# 33122  299095.1_5041146.1          3          1      18.00
# 33123  293838.2_5043304.4          7          1      42.00
# 33127  296054.0_5042655.3          4          1       0.00
# 33182  295811.6_5045920.1          4          1      33.00
# 33187  300034.5_5039630.1          9          1       0.00
# 33227  294938.2_5043058.1          2          1      12.00
# 33249  305332.0_5057869.1          8          1     170.00
# 33269  291058.5_5044150.5          4          1      12.00
# 33273  301815.7_5046113.6          7          1      21.00
# 33281  291021.5_5040468.5         11          1       0.00
# 33286  293915.1_5031396.9          6          1       6.00
# 33288  300466.9_5042151.1          7          1      -6.00
# 33294  298578.8_5046967.2          8          1      14.00
# 33303  302243.7_5051151.9          4          1      30.00
# 33305  302147.6_5049787.4         11          1      17.00
# 33309  295302.4_5036070.1         10          1       2.00
# 33311  288512.0_5044500.5          4          1       2.00
# 33331  298435.2_5038087.9         10          1       0.00
# 33343  298885.5_5041170.3          9          1       5.00
#
# [2124 rows x 18 columns]

# %%
# Review lead time between the declaration dates and prior inspection date, for null values
(df_null['DATE_DECLARATION'] - df_null['DATE_PRIOR_INSP']).describe()
# Out:
# count                       2116
# mean     45 days 04:31:31.871455
# std      85 days 07:08:45.898195
# min           -27 days +00:00:00
# 25%              3 days 00:00:00
# 50%             17 days 00:00:00
# 75%             45 days 00:00:00
# max           1165 days 00:00:00
# dtype: object

# %%
((df_null.groupby(['BORO_NAME'])
       .agg({'EXT_FREQ': sum, 'NO_DECLARATION':'count'}))
       .sort_values(by = ['EXT_FREQ','NO_DECLARATION'],ascending=False)
       .rename(columns={'EXT_FREQ':'EXT_QT','NO_DECLARATION':'DECL_QT'})
       .head(5))
# Out:
#                                       EXT_QT  DECL_QT
# BORO_NAME
# Villeray–Saint-Michel–Parc-Extension    0.00      606
# Rosemont–La Petite-Patrie               0.00      226
# Le Plateau-Mont-Royal                   0.00      177
# Ville-Marie                             0.00      173
# Mercier–Hochelaga-Maisonneuve           0.00      170

# %% [markdown]
# #### Populate blank values in EXT_FREQ

# %%
# Assumption that a least one extermination occurs per every declaration.

# Populate blank values in EXT_FREQ 
df_bedbugs['EXT_FREQ'].fillna(1, inplace=True)

# %% [markdown]
# #### Populate blanks with DATE_DECLARATION date

# %%
# Populate blanks with DATE_DECLARATION date
df_bedbugs['DATE_FIRST_EXT'] = df_bedbugs['DATE_FIRST_EXT'].fillna(df_bedbugs['DATE_DECLARATION'].dt.date)

# %%
print('==================NULL_VALUES==================')
# Check for null values
print(df_bedbugs.isnull().sum())

# %% [markdown]
# # Dealing with outliers

# %% [markdown]
# ### Removing outliers

# %% [markdown]
# Removal of outliers is not an applicable step in the process. It is confirmed whether multiple extermination reports are split over several declarations, which causes a high variability in the dates and extermination reports per declaration. The maximumum amount of reports per declaration is set to four as per the scope dictionary. Until the relationship between the dates is understood, the use of a binomial distribution and subsequent removal of outliers cannot be enforced at this time.

# %% [markdown]
# ### Merging Data Sets

# %%
df_bedbugs_base = df_bedbugs.copy()

# %% [markdown]
# ### Saving the processed file

# %%
df_bedbugs_base.to_csv('declarations-exterminations-punaises-de-lit-1.csv', index=False)

# %%
print('==================TYPES==================')
print(df_bedbugs_base.dtypes)
print('')
print('==================COLUMNS==================')
print(df_bedbugs.columns)
print('')
