# %% [markdown]
# # Data Dictionary

# %% [markdown]
# Source: https://www.kaggle.com/c/petfinder-adoption-prediction/data
#
# PetID - Unique hash ID of pet profile
#
# AdoptionSpeed - Categorical speed of adoption. Lower is faster. This is the value to predict. See below section for more info.
#
# Type - Type of animal (1 = Dog, 2 = Cat)
#
# Name - Name of pet (Empty if not named)
#
# Age - Age of pet when listed, in months
#
# Breed1 - Primary breed of pet (Refer to BreedLabels dictionary)
#
# Breed2 - Secondary breed of pet, if pet is of mixed breed (Refer to BreedLabels dictionary)
#
# Gender - Gender of pet (1 = Male, 2 = Female, 3 = Mixed, if profile represents group of pets)
#
# Color1 - Color 1 of pet (Refer to ColorLabels dictionary)
#
# Color2 - Color 2 of pet (Refer to ColorLabels dictionary)
#
# Color3 - Color 3 of pet (Refer to ColorLabels dictionary)
#
# MaturitySize - Size at maturity (1 = Small, 2 = Medium, 3 = Large, 4 = Extra Large, 0 = Not Specified)
#
# FurLength - Fur length (1 = Short, 2 = Medium, 3 = Long, 0 = Not Specified)
#
# Vaccinated - Pet has been vaccinated (1 = Yes, 2 = No, 3 = Not Sure)
#
# Dewormed - Pet has been dewormed (1 = Yes, 2 = No, 3 = Not Sure)
#
# Sterilized - Pet has been spayed / neutered (1 = Yes, 2 = No, 3 = Not Sure)
#
# Health - Health Condition (1 = Healthy, 2 = Minor Injury, 3 = Serious Injury, 0 = Not Specified)
#
# Quantity - Number of pets represented in profile
#
# Fee - Adoption fee (0 = Free)
#
# State - State location in Malaysia (Refer to StateLabels dictionary)
#
# RescuerID - Unique hash ID of rescuer
#
# VideoAmt - Total uploaded videos for this pet
#
# PhotoAmt - Total uploaded photos for this pet
#
# Description - Profile write-up for this pet. The primary language used is English, with some in Malay or Chinese.
#
# AdoptionSpeed
#
# Contestants are required to predict this value. The value is determined by how quickly, if at all, a pet is adopted. The values are determined in the following way: 0 - Pet was adopted on the same day as it was listed. 1 - Pet was adopted between 1 and 7 days (1st week) after being listed. 2 - Pet was adopted between 8 and 30 days (1st month) after being listed. 3 - Pet was adopted between 31 and 90 days (2nd & 3rd month) after being listed. 4 - No adoption after 100 days of being listed. (There are no pets in this dataset that waited between 90 and 100 days).

# %% [markdown]
# # Import Libraries

# %%
# import the library
# %matplotlib inline

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# sklearn :: utils
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn.metrics import confusion_matrix
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.model_selection import KFold

# sklearn :: models
from sklearn.neighbors import KNeighborsClassifier

# sklearn :: evaluation metrics
from sklearn.metrics import cohen_kappa_score

sns.set_style('whitegrid')

# %% [markdown]
# # Problem definition

# %% [markdown]
# Apply classification models to predict customers default payments

# %% [markdown]
# # Load the data

# %%
#source: https://www.kaggle.com/c/cebd-1260-spring-2019-classification/data
df_train = pd.read_csv('train.csv')
df_test_true = pd.read_csv('test.csv')

df_state_lbl = pd.read_csv('state_labels.csv')
df_breed_lbl = pd.read_csv('breed_labels.csv')
df_color_lbl = pd.read_csv('color_labels.csv')

# %%
print(df_state_lbl.columns)
print('')
print(df_breed_lbl.columns)
print('')
print(df_color_lbl.columns)
print('')
# print(df_gender.columns)
# Out:
# Index(['StateID', 'StateName'], dtype='object')
#
# Index(['BreedID', 'Type', 'BreedName'], dtype='object')
#
# Index(['ColorID', 'ColorName'], dtype='object')

# %%
df = df_train.copy()
print(df.columns)
df.T
# Out:
# Index(['Type', 'Name', 'Age', 'Breed1', 'Breed2', 'Gender', 'Color1', 'Color2',
#        'Color3', 'MaturitySize', 'FurLength', 'Vaccinated', 'Dewormed',
#        'Sterilized', 'Health', 'Quantity', 'Fee', 'State', 'RescuerID',
#        'VideoAmt', 'Description', 'PetID', 'PhotoAmt', 'AdoptionSpeed'],
#       dtype='object')
#                                                             0     \
# Type                                                           1
# Name                                    â¥â¥â¥ Lily â¥â¥â¥
# Age                                                           36
# Breed1                                                       307
# Breed2                                                         0
# Gender                                                         2
# Color1                                                         2
# Color2                                                         7
# Color3                                                         0
# MaturitySize                                                   2
# FurLength                                                      2
# Vaccinated                                                     1
# Dewormed                                                       2
# Sterilized                                                     1
# Health                                                         1
# Quantity                                                       1
# Fee                                                            0
# State                                                      41326
# RescuerID                       337914b09c2fa5460e195197e994ef98
# VideoAmt                                                       0
# Description    Adorable 3 year old Lily looking for a forever...
# PetID                                                  3f8824a3b
# PhotoAmt                                                       1
# AdoptionSpeed                                                  4
#
#                                                             1     \
# Type                                                           2
# Name                                                      Cookie
# Age                                                            3
# Breed1                                                       266
# Breed2                                                         0
# Gender                                                         1
# Color1                                                         6
# Color2                                                         7
# Color3                                                         0
# MaturitySize                                                   2
# FurLength                                                      1
# Vaccinated                                                     2
# Dewormed                                                       1
# Sterilized                                                     2
# Health                                                         1
# Quantity                                                       1
# Fee                                                            0
# State                                                      41327
# RescuerID                       4bb1ebb92158078ad54a6bb23c10dffc
# VideoAmt                                                       0
# Description    i rescue this stary kitten from market near my...
# PetID                                                  9238eb7fc
# PhotoAmt                                                       1
# AdoptionSpeed                                                  2
#
#                                                             2     \
# Type                                                           2
# Name                         Favour Speedy Abundance And Courage
# Age                                                            7
# Breed1                                                       250
# Breed2                                                       252
# Gender                                                         1
# Color1                                                         1
# Color2                                                         2
# Color3                                                         0
# MaturitySize                                                   2
# FurLength                                                      1
# Vaccinated                                                     1
# Dewormed                                                       1
# Sterilized                                                     2
# Health                                                         1
# Quantity                                                       4
# Fee                                                            0
# State                                                      41327
# RescuerID                       99ba8ce53b4d8515e417e7921563d923
# VideoAmt                                                       0
# Description    The mother was a Burmese cross and had since p...
# PetID                                                  f0a1f2b90
# PhotoAmt                                                       2
# AdoptionSpeed                                                  4
#
#                                                             3     \
# Type                                                           1
# Name                                                         NaN
# Age                                                            3
# Breed1                                                       307
# Breed2                                                         0
# Gender                                                         1
# Color1                                                         2
# Color2                                                         0
# Color3                                                         0
# MaturitySize                                                   3
# FurLength                                                      1
# Vaccinated                                                     2
# Dewormed                                                       2
# Sterilized                                                     2
# Health                                                         1
# Quantity                                                       1
# Fee                                                            0
# State                                                      41327
# RescuerID                       3f3ef74c486beba3bc87f6dbaee772bf
# VideoAmt                                                       0
# Description    This puppy is: 1. Male 2. 3 months old 3. Brow...
# PetID                                                  7d028bdea
# PhotoAmt                                                       4
# AdoptionSpeed                                                  2
#
#                                                             4     \
# Type                                                           2
# Name                                             Abandoned Kitty
# Age                                                            1
# Breed1                                                       266
# Breed2                                                         0
# Gender                                                         1
# Color1                                                         1
# Color2                                                         6
# Color3                                                         7
# MaturitySize                                                   1
# FurLength                                                      1
# Vaccinated                                                     2
# Dewormed                                                       2
# Sterilized                                                     2
# Health                                                         1
# Quantity                                                       1
# Fee                                                            0
# State                                                      41401
# RescuerID                       844f03ab8054007d4be6686f3a9702b9
# VideoAmt                                                       0
# Description    Mother cat gave birth to a litter of 3 and too...
# PetID                                                  8377bfe97
# PhotoAmt                                                       0
# AdoptionSpeed                                                  2
#
#                                            5     \
# Type                                          1
# Name                                       Duke
# Age                                           3
# Breed1                                      218
# Breed2                                        0
# Gender                                        1
# Color1                                        3
# Color2                                        5
# Color3                                        0
# MaturitySize                                  2
# FurLength                                     1
# Vaccinated                                    2
# Dewormed                                      1
# Sterilized                                    2
# Health                                        1
# Quantity                                      1
# Fee                                           0
# State                                     41326
# RescuerID      aa66486163b6cbc25ea62a34b11c9b91
# VideoAmt                                      0
# Description                  Duke has black fur
# PetID                                 965b31ba7
# PhotoAmt                                      2
# AdoptionSpeed                                 1
#
#                                                             6     \
# Type                                                           1
# Name                                                        Lila
# Age                                                            2
# Breed1                                                       307
# Breed2                                                         0
# Gender                                                         2
# Color1                                                         1
# Color2                                                         7
# Color3                                                         0
# MaturitySize                                                   1
# FurLength                                                      2
# Vaccinated                                                     2
# Dewormed                                                       1
# Sterilized                                                     2
# Health                                                         1
# Quantity                                                       1
# Fee                                                            0
# State                                                      41326
# RescuerID                       d21f689eab9b3faa1b738ecc836b4b36
# VideoAmt                                                       0
# Description    Lila is a pleasant little girl who we think is...
# PetID                                                  3760c73b1
# PhotoAmt                                                       1
# AdoptionSpeed                                                  4
#
#                                                             7     \
# Type                                                           1
# Name                                       Doggie2_Selangor Area
# Age                                                            8
# Breed1                                                       307
# Breed2                                                         0
# Gender                                                         2
# Color1                                                         6
# Color2                                                         0
# Color3                                                         0
# MaturitySize                                                   2
# FurLength                                                      1
# Vaccinated                                                     1
# Dewormed                                                       1
# Sterilized                                                     1
# Health                                                         1
# Quantity                                                       1
# Fee                                                            0
# State                                                      41336
# RescuerID                       8f955b588a9e571d8e267cd73cdd8a45
# VideoAmt                                                       0
# Description    Remember my friend – ADOPT, DON’T BUY! Keep in...
# PetID                                                  f41a7de83
# PhotoAmt                                                       2
# AdoptionSpeed                                                  4
#
#                                                             8     \
# Type                                                           2
# Name                                                         NaN
# Age                                                            1
# Breed1                                                       243
# Breed2                                                       245
# Gender                                                         2
# Color1                                                         1
# Color2                                                         2
# Color3                                                         7
# MaturitySize                                                   1
# FurLength                                                      1
# Vaccinated                                                     2
# Dewormed                                                       2
# Sterilized                                                     2
# Health                                                         2
# Quantity                                                       1
# Fee                                                            0
# State                                                      41326
# RescuerID                       2587c9957372fc186d3b95cfd12cf322
# VideoAmt                                                       0
# Description    urgent for adoption as I have no experience in...
# PetID                                                  7b660c6af
# PhotoAmt                                                       4
# AdoptionSpeed                                                  3
#
#                                                             9     \
# Type                                                           1
# Name                                                     Brother
# Age                                                            6
# Breed1                                                       307
# Breed2                                                         0
# Gender                                                         1
# Color1                                                         2
# Color2                                                         7
# Color3                                                         0
# MaturitySize                                                   1
# FurLength                                                      1
# Vaccinated                                                     1
# Dewormed                                                       1
# Sterilized                                                     2
# Health                                                         1
# Quantity                                                       1
# Fee                                                            0
# State                                                      41327
# RescuerID                       b84a2dd96249074fc4b276e55f608d21
# VideoAmt                                                       0
# Description    It's very playful and active dog, Like to play...
# PetID                                                  f94c2a347
# PhotoAmt                                                       2
# AdoptionSpeed                                                  4
#
#                                      ...                          \
# Type                                 ...
# Name                                 ...
# Age                                  ...
# Breed1                               ...
# Breed2                               ...
# Gender                               ...
# Color1                               ...
# Color2                               ...
# Color3                               ...
# MaturitySize                         ...
# FurLength                            ...
# Vaccinated                           ...
# Dewormed                             ...
# Sterilized                           ...
# Health                               ...
# Quantity                             ...
# Fee                                  ...
# State                                ...
# RescuerID                            ...
# VideoAmt                             ...
# Description                          ...
# PetID                                ...
# PhotoAmt                             ...
# AdoptionSpeed                        ...
#
#                                                             9990  \
# Type                                                           1
# Name                                                        Amos
# Age                                                            3
# Breed1                                                       239
# Breed2                                                       307
# Gender                                                         1
# Color1                                                         1
# Color2                                                         2
# Color3                                                         0
# MaturitySize                                                   2
# FurLength                                                      1
# Vaccinated                                                     3
# Dewormed                                                       3
# Sterilized                                                     2
# Health                                                         1
# Quantity                                                       1
# Fee                                                            0
# State                                                      41326
# RescuerID                       fa90fa5b1ee11c86938398b60abc32cb
# VideoAmt                                                       0
# Description    Lovely puppy looking for a home sweet home. If...
# PetID                                                  b09fa9385
# PhotoAmt                                                       2
# AdoptionSpeed                                                  3
#
#                                                             9991  \
# Type                                                           1
# Name                                                      Minnie
# Age                                                            1
# Breed1                                                       307
# Breed2                                                         0
# Gender                                                         2
# Color1                                                         1
# Color2                                                         2
# Color3                                                         0
# MaturitySize                                                   2
# FurLength                                                      1
# Vaccinated                                                     2
# Dewormed                                                       2
# Sterilized                                                     2
# Health                                                         1
# Quantity                                                       1
# Fee                                                            0
# State                                                      41326
# RescuerID                       893d9ac780c0203804dc170eee0144cd
# VideoAmt                                                       0
# Description    This minnie. She is very quiet and pampered pu...
# PetID                                                  b32339429
# PhotoAmt                                                       5
# AdoptionSpeed                                                  4
#
#                                                             9992  \
# Type                                                           2
# Name                                                    Meow Zai
# Age                                                            2
# Breed1                                                       299
# Breed2                                                         0
# Gender                                                         1
# Color1                                                         4
# Color2                                                         6
# Color3                                                         0
# MaturitySize                                                   2
# FurLength                                                      2
# Vaccinated                                                     2
# Dewormed                                                       1
# Sterilized                                                     2
# Health                                                         1
# Quantity                                                       2
# Fee                                                          100
# State                                                      41401
# RescuerID                       1faf0ae111772205cf2f28b3ecea3276
# VideoAmt                                                       0
# Description    Can eat dried food, use cat sands. Well traine...
# PetID                                                  6dbb13673
# PhotoAmt                                                       3
# AdoptionSpeed                                                  4
#
#                                                             9993  \
# Type                                                           2
# Name                                 SOS ð Owner Leaving Msia
# Age                                                           24
# Breed1                                                       266
# Breed2                                                         0
# Gender                                                         2
# Color1                                                         2
# Color2                                                         3
# Color3                                                         7
# MaturitySize                                                   2
# FurLength                                                      1
# Vaccinated                                                     1
# Dewormed                                                       1
# Sterilized                                                     1
# Health                                                         1
# Quantity                                                       1
# Fee                                                            0
# State                                                      41326
# RescuerID                       dd7e4618761fb9c590572a6a95cf8df8
# VideoAmt                                                       0
# Description    Posting on behalf of the owner. Owner is leavi...
# PetID                                                  9e7aa5866
# PhotoAmt                                                       7
# AdoptionSpeed                                                  1
#
#                                                             9994  \
# Type                                                           2
# Name                                                        Levi
# Age                                                            6
# Breed1                                                       285
# Breed2                                                       265
# Gender                                                         1
# Color1                                                         6
# Color2                                                         7
# Color3                                                         0
# MaturitySize                                                   2
# FurLength                                                      2
# Vaccinated                                                     1
# Dewormed                                                       1
# Sterilized                                                     2
# Health                                                         1
# Quantity                                                       1
# Fee                                                          200
# State                                                      41326
# RescuerID                       995cf22984882044311ce85ead68b920
# VideoAmt                                                       0
# Description    levi's is a manja cat,so clever,likes to sleep...
# PetID                                                  9e11a3158
# PhotoAmt                                                       5
# AdoptionSpeed                                                  2
#
#                                                             9995  \
# Type                                                           1
# Name                                                        Dawn
# Age                                                            1
# Breed1                                                       307
# Breed2                                                         0
# Gender                                                         2
# Color1                                                         2
# Color2                                                         5
# Color3                                                         7
# MaturitySize                                                   2
# FurLength                                                      1
# Vaccinated                                                     2
# Dewormed                                                       1
# Sterilized                                                     2
# Health                                                         1
# Quantity                                                       1
# Fee                                                            0
# State                                                      41326
# RescuerID                       42d5612bc1a78caec3e1342449cb08fd
# VideoAmt                                                       0
# Description    Dear All!! I've found my FOREVER HUMAN on 28 J...
# PetID                                                  b05d0484f
# PhotoAmt                                                      11
# AdoptionSpeed                                                  1
#
#                                                             9996  \
# Type                                                           1
# Name                                                         NaN
# Age                                                            5
# Breed1                                                       307
# Breed2                                                         0
# Gender                                                         2
# Color1                                                         5
# Color2                                                         0
# Color3                                                         0
# MaturitySize                                                   2
# FurLength                                                      2
# Vaccinated                                                     1
# Dewormed                                                       1
# Sterilized                                                     1
# Health                                                         2
# Quantity                                                       2
# Fee                                                            0
# State                                                      41330
# RescuerID                       2fb7d7718f9c7704ab9ae80d95f56597
# VideoAmt                                                       0
# Description    Two lovely pups for adoption. They are super f...
# PetID                                                  b586e1ea4
# PhotoAmt                                                       3
# AdoptionSpeed                                                  4
#
#                                                             9997  \
# Type                                                           2
# Name                                                    Isabella
# Age                                                            2
# Breed1                                                       265
# Breed2                                                         0
# Gender                                                         2
# Color1                                                         3
# Color2                                                         6
# Color3                                                         7
# MaturitySize                                                   2
# FurLength                                                      2
# Vaccinated                                                     1
# Dewormed                                                       1
# Sterilized                                                     2
# Health                                                         1
# Quantity                                                       1
# Fee                                                            0
# State                                                      41401
# RescuerID                       5e21416ee557e7470d1113dd98a7e3ae
# VideoAmt                                                       0
# Description    Kitten Isabella is one of five lovely kittens ...
# PetID                                                  13264f4f4
# PhotoAmt                                                       5
# AdoptionSpeed                                                  3
#
#                                                             9998  \
# Type                                                           1
# Name                                                      Brisco
# Age                                                            1
# Breed1                                                       307
# Breed2                                                         0
# Gender                                                         1
# Color1                                                         2
# Color2                                                         7
# Color3                                                         0
# MaturitySize                                                   2
# FurLength                                                      2
# Vaccinated                                                     1
# Dewormed                                                       1
# Sterilized                                                     2
# Health                                                         1
# Quantity                                                       1
# Fee                                                            0
# State                                                      41326
# RescuerID                       fa90fa5b1ee11c86938398b60abc32cb
# VideoAmt                                                       0
# Description    Their pregnant mother was dumped by her irresp...
# PetID                                                  3422e4906
# PhotoAmt                                                       7
# AdoptionSpeed                                                  3
#
#                                                             9999
# Type                                                           2
# Name                                                         NaN
# Age                                                            1
# Breed1                                                       266
# Breed2                                                         0
# Gender                                                         2
# Color1                                                         1
# Color2                                                         2
# Color3                                                         0
# MaturitySize                                                   1
# FurLength                                                      1
# Vaccinated                                                     2
# Dewormed                                                       2
# Sterilized                                                     2
# Health                                                         1
# Quantity                                                       1
# Fee                                                            0
# State                                                      41326
# RescuerID                       d663589ebd522d9bcc362a9ca68e4c26
# VideoAmt                                                       0
# Description    Found this little fur ball at the staircase ju...
# PetID                                                  8991aff61
# PhotoAmt                                                       4
# AdoptionSpeed                                                  3
#
# [24 rows x 10000 columns]

# %%
# check for NaNs
df.isnull().sum(axis = 0)
# Out:
# Type               0
# Name             842
# Age                0
# Breed1             0
# Breed2             0
# Gender             0
# Color1             0
# Color2             0
# Color3             0
# MaturitySize       0
# FurLength          0
# Vaccinated         0
# Dewormed           0
# Sterilized         0
# Health             0
# Quantity           0
# Fee                0
# State              0
# RescuerID          0
# VideoAmt           0
# Description        8
# PetID              0
# PhotoAmt           0
# AdoptionSpeed      0
# dtype: int64

# %% [markdown]
# # Feature Engineering

# %% [markdown]
# #### Remove columns

# %%
# TODO: remove a confusing column
del df['Description']
del df['RescuerID']
del df['Name']

# %%
df.head().T
# Out:
#                        0          1          2          3          4
# Type                   1          2          2          1          2
# Age                   36          3          7          3          1
# Breed1               307        266        250        307        266
# Breed2                 0          0        252          0          0
# Gender                 2          1          1          1          1
# Color1                 2          6          1          2          1
# Color2                 7          7          2          0          6
# Color3                 0          0          0          0          7
# MaturitySize           2          2          2          3          1
# FurLength              2          1          1          1          1
# Vaccinated             1          2          1          2          2
# Dewormed               2          1          1          2          2
# Sterilized             1          2          2          2          2
# Health                 1          1          1          1          1
# Quantity               1          1          4          1          1
# Fee                    0          0          0          0          0
# State              41326      41327      41327      41327      41401
# VideoAmt               0          0          0          0          0
# PetID          3f8824a3b  9238eb7fc  f0a1f2b90  7d028bdea  8377bfe97
# PhotoAmt               1          1          2          4          0
# AdoptionSpeed          4          2          4          2          2

# %%
print(df.columns)
# Out:
# Index(['Type', 'Age', 'Breed1', 'Breed2', 'Gender', 'Color1', 'Color2',
#        'Color3', 'MaturitySize', 'FurLength', 'Vaccinated', 'Dewormed',
#        'Sterilized', 'Health', 'Quantity', 'Fee', 'State', 'VideoAmt', 'PetID',
#        'PhotoAmt', 'AdoptionSpeed'],
#       dtype='object')

# %% [markdown]
# #### Rename columns

# %%
df.columns = ['Type', 'Age', 'Breed1', 'Breed2', 
              'GenderID', 
              'Color1', 'Color2','Color3', 
              'MaturitySize', 'FurLength', 'Vaccinated', 'Dewormed',
              'Sterilized', 'Health', 'Quantity', 'Fee', 
              'StateID', 'VideoAmt','PetID','PhotoAmt', 'AdoptionSpeed']

# %% [markdown]
# #### Get dummies

# %%
# Create a loop to transform the categorical columns to numerical
# Ref.: https://github.com/arybressane/CEBD1260-BIG-DATA-ANALYTICS/blob/master/week6/classification-credit-card-sklearn-extended.ipynb

for col in [
    'Type', 'GenderID', 'MaturitySize','FurLength', 'Vaccinated', 
    'Dewormed','Sterilized', 'Health','StateID','Quantity','Fee'
    ]:
    
    df_dummies = pd.get_dummies(df[col], prefix=col)
    df = pd.concat([df, df_dummies], axis=1)
    # Remove the original columns
    del df[col]
    
df.T
# Out:
#                      0          1          2          3          4     \
# Age                    36          3          7          3          1
# Breed1                307        266        250        307        266
# Breed2                  0          0        252          0          0
# Color1                  2          6          1          2          1
# Color2                  7          7          2          0          6
# Color3                  0          0          0          0          7
# VideoAmt                0          0          0          0          0
# PetID           3f8824a3b  9238eb7fc  f0a1f2b90  7d028bdea  8377bfe97
# PhotoAmt                1          1          2          4          0
# AdoptionSpeed           4          2          4          2          2
# Type_1                  1          0          0          1          0
# Type_2                  0          1          1          0          1
# GenderID_1              0          1          1          1          1
# GenderID_2              1          0          0          0          0
# GenderID_3              0          0          0          0          0
# MaturitySize_1          0          0          0          0          1
# MaturitySize_2          1          1          1          0          0
# MaturitySize_3          0          0          0          1          0
# MaturitySize_4          0          0          0          0          0
# FurLength_1             0          1          1          1          1
# FurLength_2             1          0          0          0          0
# FurLength_3             0          0          0          0          0
# Vaccinated_1            1          0          1          0          0
# Vaccinated_2            0          1          0          1          1
# Vaccinated_3            0          0          0          0          0
# Dewormed_1              0          1          1          0          0
# Dewormed_2              1          0          0          1          1
# Dewormed_3              0          0          0          0          0
# Sterilized_1            1          0          0          0          0
# Sterilized_2            0          1          1          1          1
# ...                   ...        ...        ...        ...        ...
# Fee_180                 0          0          0          0          0
# Fee_188                 0          0          0          0          0
# Fee_190                 0          0          0          0          0
# Fee_200                 0          0          0          0          0
# Fee_210                 0          0          0          0          0
# Fee_220                 0          0          0          0          0
# Fee_235                 0          0          0          0          0
# Fee_250                 0          0          0          0          0
# Fee_270                 0          0          0          0          0
# Fee_280                 0          0          0          0          0
# Fee_300                 0          0          0          0          0
# Fee_320                 0          0          0          0          0
# Fee_350                 0          0          0          0          0
# Fee_380                 0          0          0          0          0
# Fee_385                 0          0          0          0          0
# Fee_390                 0          0          0          0          0
# Fee_400                 0          0          0          0          0
# Fee_450                 0          0          0          0          0
# Fee_480                 0          0          0          0          0
# Fee_499                 0          0          0          0          0
# Fee_500                 0          0          0          0          0
# Fee_550                 0          0          0          0          0
# Fee_600                 0          0          0          0          0
# Fee_650                 0          0          0          0          0
# Fee_700                 0          0          0          0          0
# Fee_750                 0          0          0          0          0
# Fee_800                 0          0          0          0          0
# Fee_1000                0          0          0          0          0
# Fee_2000                0          0          0          0          0
# Fee_3000                0          0          0          0          0
#
#                      5          6          7          8          9     \
# Age                     3          2          8          1          6
# Breed1                218        307        307        243        307
# Breed2                  0          0          0        245          0
# Color1                  3          1          6          1          2
# Color2                  5          7          0          2          7
# Color3                  0          0          0          7          0
# VideoAmt                0          0          0          0          0
# PetID           965b31ba7  3760c73b1  f41a7de83  7b660c6af  f94c2a347
# PhotoAmt                2          1          2          4          2
# AdoptionSpeed           1          4          4          3          4
# Type_1                  1          1          1          0          1
# Type_2                  0          0          0          1          0
# GenderID_1              1          0          0          0          1
# GenderID_2              0          1          1          1          0
# GenderID_3              0          0          0          0          0
# MaturitySize_1          0          1          0          1          1
# MaturitySize_2          1          0          1          0          0
# MaturitySize_3          0          0          0          0          0
# MaturitySize_4          0          0          0          0          0
# FurLength_1             1          0          1          1          1
# FurLength_2             0          1          0          0          0
# FurLength_3             0          0          0          0          0
# Vaccinated_1            0          0          1          0          1
# Vaccinated_2            1          1          0          1          0
# Vaccinated_3            0          0          0          0          0
# Dewormed_1              1          1          1          0          1
# Dewormed_2              0          0          0          1          0
# Dewormed_3              0          0          0          0          0
# Sterilized_1            0          0          1          0          0
# Sterilized_2            1          1          0          1          1
# ...                   ...        ...        ...        ...        ...
# Fee_180                 0          0          0          0          0
# Fee_188                 0          0          0          0          0
# Fee_190                 0          0          0          0          0
# Fee_200                 0          0          0          0          0
# Fee_210                 0          0          0          0          0
# Fee_220                 0          0          0          0          0
# Fee_235                 0          0          0          0          0
# Fee_250                 0          0          0          0          0
# Fee_270                 0          0          0          0          0
# Fee_280                 0          0          0          0          0
# Fee_300                 0          0          0          0          0
# Fee_320                 0          0          0          0          0
# Fee_350                 0          0          0          0          0
# Fee_380                 0          0          0          0          0
# Fee_385                 0          0          0          0          0
# Fee_390                 0          0          0          0          0
# Fee_400                 0          0          0          0          0
# Fee_450                 0          0          0          0          0
# Fee_480                 0          0          0          0          0
# Fee_499                 0          0          0          0          0
# Fee_500                 0          0          0          0          0
# Fee_550                 0          0          0          0          0
# Fee_600                 0          0          0          0          0
# Fee_650                 0          0          0          0          0
# Fee_700                 0          0          0          0          0
# Fee_750                 0          0          0          0          0
# Fee_800                 0          0          0          0          0
# Fee_1000                0          0          0          0          0
# Fee_2000                0          0          0          0          0
# Fee_3000                0          0          0          0          0
#
#                   ...           9990       9991       9992       9993  \
# Age               ...              3          1          2         24
# Breed1            ...            239        307        299        266
# Breed2            ...            307          0          0          0
# Color1            ...              1          1          4          2
# Color2            ...              2          2          6          3
# Color3            ...              0          0          0          7
# VideoAmt          ...              0          0          0          0
# PetID             ...      b09fa9385  b32339429  6dbb13673  9e7aa5866
# PhotoAmt          ...              2          5          3          7
# AdoptionSpeed     ...              3          4          4          1
# Type_1            ...              1          1          0          0
# Type_2            ...              0          0          1          1
# GenderID_1        ...              1          0          1          0
# GenderID_2        ...              0          1          0          1
# GenderID_3        ...              0          0          0          0
# MaturitySize_1    ...              0          0          0          0
# MaturitySize_2    ...              1          1          1          1
# MaturitySize_3    ...              0          0          0          0
# MaturitySize_4    ...              0          0          0          0
# FurLength_1       ...              1          1          0          1
# FurLength_2       ...              0          0          1          0
# FurLength_3       ...              0          0          0          0
# Vaccinated_1      ...              0          0          0          1
# Vaccinated_2      ...              0          1          1          0
# Vaccinated_3      ...              1          0          0          0
# Dewormed_1        ...              0          0          1          1
# Dewormed_2        ...              0          1          0          0
# Dewormed_3        ...              1          0          0          0
# Sterilized_1      ...              0          0          0          1
# Sterilized_2      ...              1          1          1          0
# ...               ...            ...        ...        ...        ...
# Fee_180           ...              0          0          0          0
# Fee_188           ...              0          0          0          0
# Fee_190           ...              0          0          0          0
# Fee_200           ...              0          0          0          0
# Fee_210           ...              0          0          0          0
# Fee_220           ...              0          0          0          0
# Fee_235           ...              0          0          0          0
# Fee_250           ...              0          0          0          0
# Fee_270           ...              0          0          0          0
# Fee_280           ...              0          0          0          0
# Fee_300           ...              0          0          0          0
# Fee_320           ...              0          0          0          0
# Fee_350           ...              0          0          0          0
# Fee_380           ...              0          0          0          0
# Fee_385           ...              0          0          0          0
# Fee_390           ...              0          0          0          0
# Fee_400           ...              0          0          0          0
# Fee_450           ...              0          0          0          0
# Fee_480           ...              0          0          0          0
# Fee_499           ...              0          0          0          0
# Fee_500           ...              0          0          0          0
# Fee_550           ...              0          0          0          0
# Fee_600           ...              0          0          0          0
# Fee_650           ...              0          0          0          0
# Fee_700           ...              0          0          0          0
# Fee_750           ...              0          0          0          0
# Fee_800           ...              0          0          0          0
# Fee_1000          ...              0          0          0          0
# Fee_2000          ...              0          0          0          0
# Fee_3000          ...              0          0          0          0
#
#                      9994       9995       9996       9997       9998  \
# Age                     6          1          5          2          1
# Breed1                285        307        307        265        307
# Breed2                265          0          0          0          0
# Color1                  6          2          5          3          2
# Color2                  7          5          0          6          7
# Color3                  0          7          0          7          0
# VideoAmt                0          0          0          0          0
# PetID           9e11a3158  b05d0484f  b586e1ea4  13264f4f4  3422e4906
# PhotoAmt                5         11          3          5          7
# AdoptionSpeed           2          1          4          3          3
# Type_1                  0          1          1          0          1
# Type_2                  1          0          0          1          0
# GenderID_1              1          0          0          0          1
# GenderID_2              0          1          1          1          0
# GenderID_3              0          0          0          0          0
# MaturitySize_1          0          0          0          0          0
# MaturitySize_2          1          1          1          1          1
# MaturitySize_3          0          0          0          0          0
# MaturitySize_4          0          0          0          0          0
# FurLength_1             0          1          0          0          0
# FurLength_2             1          0          1          1          1
# FurLength_3             0          0          0          0          0
# Vaccinated_1            1          0          1          1          1
# Vaccinated_2            0          1          0          0          0
# Vaccinated_3            0          0          0          0          0
# Dewormed_1              1          1          1          1          1
# Dewormed_2              0          0          0          0          0
# Dewormed_3              0          0          0          0          0
# Sterilized_1            0          0          1          0          0
# Sterilized_2            1          1          0          1          1
# ...                   ...        ...        ...        ...        ...
# Fee_180                 0          0          0          0          0
# Fee_188                 0          0          0          0          0
# Fee_190                 0          0          0          0          0
# Fee_200                 1          0          0          0          0
# Fee_210                 0          0          0          0          0
# Fee_220                 0          0          0          0          0
# Fee_235                 0          0          0          0          0
# Fee_250                 0          0          0          0          0
# Fee_270                 0          0          0          0          0
# Fee_280                 0          0          0          0          0
# Fee_300                 0          0          0          0          0
# Fee_320                 0          0          0          0          0
# Fee_350                 0          0          0          0          0
# Fee_380                 0          0          0          0          0
# Fee_385                 0          0          0          0          0
# Fee_390                 0          0          0          0          0
# Fee_400                 0          0          0          0          0
# Fee_450                 0          0          0          0          0
# Fee_480                 0          0          0          0          0
# Fee_499                 0          0          0          0          0
# Fee_500                 0          0          0          0          0
# Fee_550                 0          0          0          0          0
# Fee_600                 0          0          0          0          0
# Fee_650                 0          0          0          0          0
# Fee_700                 0          0          0          0          0
# Fee_750                 0          0          0          0          0
# Fee_800                 0          0          0          0          0
# Fee_1000                0          0          0          0          0
# Fee_2000                0          0          0          0          0
# Fee_3000                0          0          0          0          0
#
#                      9999
# Age                     1
# Breed1                266
# Breed2                  0
# Color1                  1
# Color2                  2
# Color3                  0
# VideoAmt                0
# PetID           8991aff61
# PhotoAmt                4
# AdoptionSpeed           3
# Type_1                  0
# Type_2                  1
# GenderID_1              0
# GenderID_2              1
# GenderID_3              0
# MaturitySize_1          1
# MaturitySize_2          0
# MaturitySize_3          0
# MaturitySize_4          0
# FurLength_1             1
# FurLength_2             0
# FurLength_3             0
# Vaccinated_1            0
# Vaccinated_2            1
# Vaccinated_3            0
# Dewormed_1              0
# Dewormed_2              1
# Dewormed_3              0
# Sterilized_1            0
# Sterilized_2            1
# ...                   ...
# Fee_180                 0
# Fee_188                 0
# Fee_190                 0
# Fee_200                 0
# Fee_210                 0
# Fee_220                 0
# Fee_235                 0
# Fee_250                 0
# Fee_270                 0
# Fee_280                 0
# Fee_300                 0
# Fee_320                 0
# Fee_350                 0
# Fee_380                 0
# Fee_385                 0
# Fee_390                 0
# Fee_400                 0
# Fee_450                 0
# Fee_480                 0
# Fee_499                 0
# Fee_500                 0
# Fee_550                 0
# Fee_600                 0
# Fee_650                 0
# Fee_700                 0
# Fee_750                 0
# Fee_800                 0
# Fee_1000                0
# Fee_2000                0
# Fee_3000                0
#
# [132 rows x 10000 columns]

# %%
print(df.columns)
# Out:
# Index(['Age', 'Breed1', 'Breed2', 'Color1', 'Color2', 'Color3', 'VideoAmt',
#        'PetID', 'PhotoAmt', 'AdoptionSpeed',
#        ...
#        'Fee_500', 'Fee_550', 'Fee_600', 'Fee_650', 'Fee_700', 'Fee_750',
#        'Fee_800', 'Fee_1000', 'Fee_2000', 'Fee_3000'],
#       dtype='object', length=132)

# %%
df.T
# Out:
#                      0          1          2          3          4     \
# Age                    36          3          7          3          1
# Breed1                307        266        250        307        266
# Breed2                  0          0        252          0          0
# Color1                  2          6          1          2          1
# Color2                  7          7          2          0          6
# Color3                  0          0          0          0          7
# VideoAmt                0          0          0          0          0
# PetID           3f8824a3b  9238eb7fc  f0a1f2b90  7d028bdea  8377bfe97
# PhotoAmt                1          1          2          4          0
# AdoptionSpeed           4          2          4          2          2
# Type_1                  1          0          0          1          0
# Type_2                  0          1          1          0          1
# GenderID_1              0          1          1          1          1
# GenderID_2              1          0          0          0          0
# GenderID_3              0          0          0          0          0
# MaturitySize_1          0          0          0          0          1
# MaturitySize_2          1          1          1          0          0
# MaturitySize_3          0          0          0          1          0
# MaturitySize_4          0          0          0          0          0
# FurLength_1             0          1          1          1          1
# FurLength_2             1          0          0          0          0
# FurLength_3             0          0          0          0          0
# Vaccinated_1            1          0          1          0          0
# Vaccinated_2            0          1          0          1          1
# Vaccinated_3            0          0          0          0          0
# Dewormed_1              0          1          1          0          0
# Dewormed_2              1          0          0          1          1
# Dewormed_3              0          0          0          0          0
# Sterilized_1            1          0          0          0          0
# Sterilized_2            0          1          1          1          1
# ...                   ...        ...        ...        ...        ...
# Fee_180                 0          0          0          0          0
# Fee_188                 0          0          0          0          0
# Fee_190                 0          0          0          0          0
# Fee_200                 0          0          0          0          0
# Fee_210                 0          0          0          0          0
# Fee_220                 0          0          0          0          0
# Fee_235                 0          0          0          0          0
# Fee_250                 0          0          0          0          0
# Fee_270                 0          0          0          0          0
# Fee_280                 0          0          0          0          0
# Fee_300                 0          0          0          0          0
# Fee_320                 0          0          0          0          0
# Fee_350                 0          0          0          0          0
# Fee_380                 0          0          0          0          0
# Fee_385                 0          0          0          0          0
# Fee_390                 0          0          0          0          0
# Fee_400                 0          0          0          0          0
# Fee_450                 0          0          0          0          0
# Fee_480                 0          0          0          0          0
# Fee_499                 0          0          0          0          0
# Fee_500                 0          0          0          0          0
# Fee_550                 0          0          0          0          0
# Fee_600                 0          0          0          0          0
# Fee_650                 0          0          0          0          0
# Fee_700                 0          0          0          0          0
# Fee_750                 0          0          0          0          0
# Fee_800                 0          0          0          0          0
# Fee_1000                0          0          0          0          0
# Fee_2000                0          0          0          0          0
# Fee_3000                0          0          0          0          0
#
#                      5          6          7          8          9     \
# Age                     3          2          8          1          6
# Breed1                218        307        307        243        307
# Breed2                  0          0          0        245          0
# Color1                  3          1          6          1          2
# Color2                  5          7          0          2          7
# Color3                  0          0          0          7          0
# VideoAmt                0          0          0          0          0
# PetID           965b31ba7  3760c73b1  f41a7de83  7b660c6af  f94c2a347
# PhotoAmt                2          1          2          4          2
# AdoptionSpeed           1          4          4          3          4
# Type_1                  1          1          1          0          1
# Type_2                  0          0          0          1          0
# GenderID_1              1          0          0          0          1
# GenderID_2              0          1          1          1          0
# GenderID_3              0          0          0          0          0
# MaturitySize_1          0          1          0          1          1
# MaturitySize_2          1          0          1          0          0
# MaturitySize_3          0          0          0          0          0
# MaturitySize_4          0          0          0          0          0
# FurLength_1             1          0          1          1          1
# FurLength_2             0          1          0          0          0
# FurLength_3             0          0          0          0          0
# Vaccinated_1            0          0          1          0          1
# Vaccinated_2            1          1          0          1          0
# Vaccinated_3            0          0          0          0          0
# Dewormed_1              1          1          1          0          1
# Dewormed_2              0          0          0          1          0
# Dewormed_3              0          0          0          0          0
# Sterilized_1            0          0          1          0          0
# Sterilized_2            1          1          0          1          1
# ...                   ...        ...        ...        ...        ...
# Fee_180                 0          0          0          0          0
# Fee_188                 0          0          0          0          0
# Fee_190                 0          0          0          0          0
# Fee_200                 0          0          0          0          0
# Fee_210                 0          0          0          0          0
# Fee_220                 0          0          0          0          0
# Fee_235                 0          0          0          0          0
# Fee_250                 0          0          0          0          0
# Fee_270                 0          0          0          0          0
# Fee_280                 0          0          0          0          0
# Fee_300                 0          0          0          0          0
# Fee_320                 0          0          0          0          0
# Fee_350                 0          0          0          0          0
# Fee_380                 0          0          0          0          0
# Fee_385                 0          0          0          0          0
# Fee_390                 0          0          0          0          0
# Fee_400                 0          0          0          0          0
# Fee_450                 0          0          0          0          0
# Fee_480                 0          0          0          0          0
# Fee_499                 0          0          0          0          0
# Fee_500                 0          0          0          0          0
# Fee_550                 0          0          0          0          0
# Fee_600                 0          0          0          0          0
# Fee_650                 0          0          0          0          0
# Fee_700                 0          0          0          0          0
# Fee_750                 0          0          0          0          0
# Fee_800                 0          0          0          0          0
# Fee_1000                0          0          0          0          0
# Fee_2000                0          0          0          0          0
# Fee_3000                0          0          0          0          0
#
#                   ...           9990       9991       9992       9993  \
# Age               ...              3          1          2         24
# Breed1            ...            239        307        299        266
# Breed2            ...            307          0          0          0
# Color1            ...              1          1          4          2
# Color2            ...              2          2          6          3
# Color3            ...              0          0          0          7
# VideoAmt          ...              0          0          0          0
# PetID             ...      b09fa9385  b32339429  6dbb13673  9e7aa5866
# PhotoAmt          ...              2          5          3          7
# AdoptionSpeed     ...              3          4          4          1
# Type_1            ...              1          1          0          0
# Type_2            ...              0          0          1          1
# GenderID_1        ...              1          0          1          0
# GenderID_2        ...              0          1          0          1
# GenderID_3        ...              0          0          0          0
# MaturitySize_1    ...              0          0          0          0
# MaturitySize_2    ...              1          1          1          1
# MaturitySize_3    ...              0          0          0          0
# MaturitySize_4    ...              0          0          0          0
# FurLength_1       ...              1          1          0          1
# FurLength_2       ...              0          0          1          0
# FurLength_3       ...              0          0          0          0
# Vaccinated_1      ...              0          0          0          1
# Vaccinated_2      ...              0          1          1          0
# Vaccinated_3      ...              1          0          0          0
# Dewormed_1        ...              0          0          1          1
# Dewormed_2        ...              0          1          0          0
# Dewormed_3        ...              1          0          0          0
# Sterilized_1      ...              0          0          0          1
# Sterilized_2      ...              1          1          1          0
# ...               ...            ...        ...        ...        ...
# Fee_180           ...              0          0          0          0
# Fee_188           ...              0          0          0          0
# Fee_190           ...              0          0          0          0
# Fee_200           ...              0          0          0          0
# Fee_210           ...              0          0          0          0
# Fee_220           ...              0          0          0          0
# Fee_235           ...              0          0          0          0
# Fee_250           ...              0          0          0          0
# Fee_270           ...              0          0          0          0
# Fee_280           ...              0          0          0          0
# Fee_300           ...              0          0          0          0
# Fee_320           ...              0          0          0          0
# Fee_350           ...              0          0          0          0
# Fee_380           ...              0          0          0          0
# Fee_385           ...              0          0          0          0
# Fee_390           ...              0          0          0          0
# Fee_400           ...              0          0          0          0
# Fee_450           ...              0          0          0          0
# Fee_480           ...              0          0          0          0
# Fee_499           ...              0          0          0          0
# Fee_500           ...              0          0          0          0
# Fee_550           ...              0          0          0          0
# Fee_600           ...              0          0          0          0
# Fee_650           ...              0          0          0          0
# Fee_700           ...              0          0          0          0
# Fee_750           ...              0          0          0          0
# Fee_800           ...              0          0          0          0
# Fee_1000          ...              0          0          0          0
# Fee_2000          ...              0          0          0          0
# Fee_3000          ...              0          0          0          0
#
#                      9994       9995       9996       9997       9998  \
# Age                     6          1          5          2          1
# Breed1                285        307        307        265        307
# Breed2                265          0          0          0          0
# Color1                  6          2          5          3          2
# Color2                  7          5          0          6          7
# Color3                  0          7          0          7          0
# VideoAmt                0          0          0          0          0
# PetID           9e11a3158  b05d0484f  b586e1ea4  13264f4f4  3422e4906
# PhotoAmt                5         11          3          5          7
# AdoptionSpeed           2          1          4          3          3
# Type_1                  0          1          1          0          1
# Type_2                  1          0          0          1          0
# GenderID_1              1          0          0          0          1
# GenderID_2              0          1          1          1          0
# GenderID_3              0          0          0          0          0
# MaturitySize_1          0          0          0          0          0
# MaturitySize_2          1          1          1          1          1
# MaturitySize_3          0          0          0          0          0
# MaturitySize_4          0          0          0          0          0
# FurLength_1             0          1          0          0          0
# FurLength_2             1          0          1          1          1
# FurLength_3             0          0          0          0          0
# Vaccinated_1            1          0          1          1          1
# Vaccinated_2            0          1          0          0          0
# Vaccinated_3            0          0          0          0          0
# Dewormed_1              1          1          1          1          1
# Dewormed_2              0          0          0          0          0
# Dewormed_3              0          0          0          0          0
# Sterilized_1            0          0          1          0          0
# Sterilized_2            1          1          0          1          1
# ...                   ...        ...        ...        ...        ...
# Fee_180                 0          0          0          0          0
# Fee_188                 0          0          0          0          0
# Fee_190                 0          0          0          0          0
# Fee_200                 1          0          0          0          0
# Fee_210                 0          0          0          0          0
# Fee_220                 0          0          0          0          0
# Fee_235                 0          0          0          0          0
# Fee_250                 0          0          0          0          0
# Fee_270                 0          0          0          0          0
# Fee_280                 0          0          0          0          0
# Fee_300                 0          0          0          0          0
# Fee_320                 0          0          0          0          0
# Fee_350                 0          0          0          0          0
# Fee_380                 0          0          0          0          0
# Fee_385                 0          0          0          0          0
# Fee_390                 0          0          0          0          0
# Fee_400                 0          0          0          0          0
# Fee_450                 0          0          0          0          0
# Fee_480                 0          0          0          0          0
# Fee_499                 0          0          0          0          0
# Fee_500                 0          0          0          0          0
# Fee_550                 0          0          0          0          0
# Fee_600                 0          0          0          0          0
# Fee_650                 0          0          0          0          0
# Fee_700                 0          0          0          0          0
# Fee_750                 0          0          0          0          0
# Fee_800                 0          0          0          0          0
# Fee_1000                0          0          0          0          0
# Fee_2000                0          0          0          0          0
# Fee_3000                0          0          0          0          0
#
#                      9999
# Age                     1
# Breed1                266
# Breed2                  0
# Color1                  1
# Color2                  2
# Color3                  0
# VideoAmt                0
# PetID           8991aff61
# PhotoAmt                4
# AdoptionSpeed           3
# Type_1                  0
# Type_2                  1
# GenderID_1              0
# GenderID_2              1
# GenderID_3              0
# MaturitySize_1          1
# MaturitySize_2          0
# MaturitySize_3          0
# MaturitySize_4          0
# FurLength_1             1
# FurLength_2             0
# FurLength_3             0
# Vaccinated_1            0
# Vaccinated_2            1
# Vaccinated_3            0
# Dewormed_1              0
# Dewormed_2              1
# Dewormed_3              0
# Sterilized_1            0
# Sterilized_2            1
# ...                   ...
# Fee_180                 0
# Fee_188                 0
# Fee_190                 0
# Fee_200                 0
# Fee_210                 0
# Fee_220                 0
# Fee_235                 0
# Fee_250                 0
# Fee_270                 0
# Fee_280                 0
# Fee_300                 0
# Fee_320                 0
# Fee_350                 0
# Fee_380                 0
# Fee_385                 0
# Fee_390                 0
# Fee_400                 0
# Fee_450                 0
# Fee_480                 0
# Fee_499                 0
# Fee_500                 0
# Fee_550                 0
# Fee_600                 0
# Fee_650                 0
# Fee_700                 0
# Fee_750                 0
# Fee_800                 0
# Fee_1000                0
# Fee_2000                0
# Fee_3000                0
#
# [132 rows x 10000 columns]

# %%
X_columns = ['Age', 
             'Breed1', 'Breed2', 
             'Color1', 'Color2', 'Color3', 
             'Quantity_1', 
             'Fee_0', 
             #'VideoAmt', 
             #'PhotoAmt', 
             'Type_1', 'Type_2',
             'GenderID_1', 'GenderID_2', 'GenderID_3', 
             #'MaturitySize_1','MaturitySize_2', 'MaturitySize_3', 'MaturitySize_4', 
             'FurLength_1','FurLength_2', 'FurLength_3', 
             'Vaccinated_1', 'Vaccinated_2','Vaccinated_3', 
             'Dewormed_1', 'Dewormed_2', 'Dewormed_3',
             'Sterilized_1', 'Sterilized_2', 'Sterilized_3', 
             'Health_1', 'Health_2','Health_3',
             'StateID_41324', 'StateID_41325', 'StateID_41326', 'StateID_41327', 
             'StateID_41330', 'StateID_41332', 'StateID_41335', 'StateID_41336', 
             'StateID_41342', 'StateID_41345', 'StateID_41361',
             'StateID_41367', 'StateID_41401', 'StateID_41415'
            ]

# X_columns = [x for x in df.columns 
#              if x != 'AdoptionSpeed' and x != 'PetID']


y_column = ['AdoptionSpeed']

# %%
# list(X_columns)

# %% [markdown]
# # Model Training

# %%
# Ref.: https://github.com/arybressane/CEBD1260-BIG-DATA-ANALYTICS/blob/master/week6/kaggle_submission_pets.ipynb

# %%
# split the data

threshold = 0.8
X = df[X_columns]
y = df[y_column]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=1.0-threshold, shuffle=True)

print('X_train', X_train.shape)
print('y_train', y_train.shape)
print('X_test', X_test.shape)
print('y_test', y_test.shape)
# Out:
# X_train (8000, 42)
# y_train (8000, 1)
# X_test (2000, 42)
# y_test (2000, 1)

# %%
# train a KNN Classifier
model = KNeighborsClassifier()
model.fit(X_train, y_train.values.ravel())
y_pred = model.predict(X_test)

# %% [markdown]
# # Model Training / Evaluation - Using Split

# %%
kappa = cohen_kappa_score(y_test, y_pred, weights ='quadratic')
print('kappa', round(kappa, 4))
print(confusion_matrix(y_test, y_pred))
# Out:
# kappa 0.2489
# [[  5  21  11  10   6]
#  [  9 166 133  60  50]
#  [ 12 150 213  95  89]
#  [  6  89 143  96  80]
#  [  8 103 134 111 200]]

# %%
importance = []
if hasattr(model, 'feature_importances_'):
    print('Feature Importance')
    importance = []
    for i in range(len(X_columns)):
        importance.append([X_columns[i], model.feature_importances_[i]])
    print(pd.DataFrame(importance).sort_values(by=1, ascending=False).head(10))
elif hasattr(model, 'coef_'):
    print('Feature Importance')
    for i in range(len(X_columns)):
        importance.append([X_columns[i], model.coef_[i]])
    print(pd.DataFrame(importance).sort_values(by=1, ascending=False).head(10))
        
print('')

# %% [markdown]
# # Model Training / Evaluation - Cross Validation

# %%
k = 10
results = []
kf = KFold(n_splits=k)
for train_index, test_index in kf.split(X):
    X_train, X_test = X.values[train_index], X.values[test_index]
    y_train, y_test = y.values[train_index], y.values[test_index]
    model.fit(X_train, y_train.ravel())
    y_pred = model.predict(X_test)
    kappa = cohen_kappa_score(y_test, y_pred, weights ='quadratic')
    results.append(round(kappa, 4))

print('Kappa for each fold:', results)
print('AVG(kappa)', round(np.mean(results), 4))
print('STD(kappa)', round(np.std(results), 4))
# Out:
# Kappa for each fold: [0.23, 0.2117, 0.2241, 0.2453, 0.1458, 0.191, 0.1853, 0.2184, 0.2025, 0.2245]
# AVG(kappa) 0.2079
# STD(kappa) 0.0269

# %% [markdown]
# # Prepare submission

# %%
del df_test_true['Description']
del df_test_true['RescuerID']
del df_test_true['Name']
df_test_true.columns
# Out:
# Index(['Type', 'Age', 'Breed1', 'Breed2', 'Gender', 'Color1', 'Color2',
#        'Color3', 'MaturitySize', 'FurLength', 'Vaccinated', 'Dewormed',
#        'Sterilized', 'Health', 'Quantity', 'Fee', 'State', 'VideoAmt', 'PetID',
#        'PhotoAmt'],
#       dtype='object')

# %%
df_test_true.columns = ['Type', 'Age', 'Breed1', 'Breed2', 
              'GenderID', 
              'Color1', 'Color2','Color3', 
              'MaturitySize', 'FurLength', 'Vaccinated', 'Dewormed',
              'Sterilized', 'Health', 'Quantity', 'Fee', 
              'StateID', 'VideoAmt','PetID','PhotoAmt']

# %%
for col in [
    'Type', 'GenderID', 'MaturitySize','FurLength', 'Vaccinated', 
    'Dewormed','Sterilized', 'Health','StateID','Quantity','Fee'
    ]:
    
    df_dummies = pd.get_dummies(df_test_true[col], prefix=col)
    df_test_true = pd.concat([df_test_true, df_dummies], axis=1)
    # Remove the original columns
    del df_test_true[col]
    
df_test_true.T
# Out:
#                      0          1          2          3          4     \
# Age                     1          6          2         10         12
# Breed1                266        307        307        128        307
# Breed2                266          0          0          0          0
# Color1                  1          2          3          7          2
# Color2                  7          0          0          0          0
# Color3                  0          0          0          0          0
# VideoAmt                0          0          0          0          0
# PetID           f42161740  0118db3a8  e5164d828  5335bfb38  ff2cf88a0
# PhotoAmt               10          2          2          0          2
# Type_1                  0          1          1          1          1
# Type_2                  1          0          0          0          0
# GenderID_1              1          0          0          1          1
# GenderID_2              0          1          1          0          0
# GenderID_3              0          0          0          0          0
# MaturitySize_1          0          1          0          0          0
# MaturitySize_2          1          0          1          1          1
# MaturitySize_3          0          0          0          0          0
# MaturitySize_4          0          0          0          0          0
# FurLength_1             1          1          1          0          1
# FurLength_2             0          0          0          1          0
# FurLength_3             0          0          0          0          0
# Vaccinated_1            0          1          0          1          1
# Vaccinated_2            1          0          0          0          0
# Vaccinated_3            0          0          1          0          0
# Dewormed_1              0          1          1          1          1
# Dewormed_2              1          0          0          0          0
# Dewormed_3              0          0          0          0          0
# Sterilized_1            0          0          0          0          1
# Sterilized_2            1          1          1          1          0
# Sterilized_3            0          0          0          0          0
# ...                   ...        ...        ...        ...        ...
# Fee_100                 0          0          0          0          0
# Fee_108                 0          0          0          0          0
# Fee_110                 0          0          0          0          0
# Fee_120                 0          0          0          0          0
# Fee_125                 0          0          0          0          0
# Fee_135                 0          0          0          0          0
# Fee_150                 0          0          0          0          0
# Fee_155                 0          0          0          0          0
# Fee_160                 0          0          0          0          0
# Fee_180                 0          0          0          0          0
# Fee_188                 0          0          0          0          0
# Fee_200                 0          0          0          0          0
# Fee_220                 0          0          0          0          0
# Fee_250                 0          0          0          0          0
# Fee_270                 0          0          0          0          0
# Fee_280                 0          0          0          0          0
# Fee_299                 0          0          0          0          0
# Fee_300                 0          0          0          0          0
# Fee_330                 0          0          0          0          0
# Fee_350                 0          0          0          0          0
# Fee_390                 0          0          0          0          0
# Fee_400                 0          0          0          0          0
# Fee_450                 0          0          0          0          0
# Fee_500                 0          0          0          0          0
# Fee_550                 0          0          0          0          0
# Fee_599                 0          0          0          0          0
# Fee_600                 0          0          0          0          0
# Fee_688                 0          0          0          0          0
# Fee_700                 0          0          0          0          0
# Fee_750                 0          0          0          0          0
#
#                      5          6          7          8          9     \
# Age                     1          4          3          2          2
# Breed1                266        266        307        307        265
# Breed2                  0          0          0          0          0
# Color1                  1          2          1          1          4
# Color2                  2          3          0          2          7
# Color3                  0          7          0          0          0
# VideoAmt                0          0          0          0          0
# PetID           1d13441b9  7d835cf7c  577d15fea  91736f444  db194aec8
# PhotoAmt                1          9          1          4          6
# Type_1                  0          0          1          1          0
# Type_2                  1          1          0          0          1
# GenderID_1              0          0          0          0          0
# GenderID_2              1          0          1          0          0
# GenderID_3              0          1          0          1          1
# MaturitySize_1          1          1          0          0          1
# MaturitySize_2          0          0          1          1          0
# MaturitySize_3          0          0          0          0          0
# MaturitySize_4          0          0          0          0          0
# FurLength_1             1          1          0          1          1
# FurLength_2             0          0          1          0          0
# FurLength_3             0          0          0          0          0
# Vaccinated_1            0          0          1          0          0
# Vaccinated_2            1          1          0          1          1
# Vaccinated_3            0          0          0          0          0
# Dewormed_1              0          1          1          0          0
# Dewormed_2              1          0          0          1          1
# Dewormed_3              0          0          0          0          0
# Sterilized_1            0          0          0          0          0
# Sterilized_2            1          1          1          1          1
# Sterilized_3            0          0          0          0          0
# ...                   ...        ...        ...        ...        ...
# Fee_100                 0          0          0          0          0
# Fee_108                 0          0          0          0          0
# Fee_110                 0          0          0          0          0
# Fee_120                 0          0          0          0          0
# Fee_125                 0          0          0          0          0
# Fee_135                 0          0          0          0          0
# Fee_150                 0          0          0          0          0
# Fee_155                 0          0          0          0          0
# Fee_160                 0          0          0          0          0
# Fee_180                 0          0          0          0          0
# Fee_188                 0          0          0          0          0
# Fee_200                 0          0          0          0          0
# Fee_220                 0          0          0          0          0
# Fee_250                 0          0          0          0          0
# Fee_270                 0          0          0          0          0
# Fee_280                 0          0          0          0          0
# Fee_299                 0          0          0          0          0
# Fee_300                 0          0          0          0          0
# Fee_330                 0          0          0          0          0
# Fee_350                 0          0          0          0          0
# Fee_390                 0          0          0          0          0
# Fee_400                 0          0          0          0          0
# Fee_450                 0          0          0          0          0
# Fee_500                 0          0          0          0          0
# Fee_550                 0          0          0          0          0
# Fee_599                 0          0          0          0          0
# Fee_600                 0          0          0          0          0
# Fee_688                 0          0          0          0          0
# Fee_700                 0          0          0          0          0
# Fee_750                 0          0          0          0          0
#
#                   ...           4983       4984       4985       4986  \
# Age               ...              4          5          1         18
# Breed1            ...            307        266        266        266
# Breed2            ...            307          0          0          0
# Color1            ...              2          7          1          6
# Color2            ...              0          0          7          7
# Color3            ...              0          0          0          0
# VideoAmt          ...              0          0          1          1
# PetID             ...      878e36da4  46cf6356e  ef50eab33  a40116bf1
# PhotoAmt          ...              3          1          4          2
# Type_1            ...              1          0          0          0
# Type_2            ...              0          1          1          1
# GenderID_1        ...              0          1          0          0
# GenderID_2        ...              1          0          0          1
# GenderID_3        ...              0          0          1          0
# MaturitySize_1    ...              0          0          1          1
# MaturitySize_2    ...              1          1          0          0
# MaturitySize_3    ...              0          0          0          0
# MaturitySize_4    ...              0          0          0          0
# FurLength_1       ...              1          1          1          1
# FurLength_2       ...              0          0          0          0
# FurLength_3       ...              0          0          0          0
# Vaccinated_1      ...              1          0          0          0
# Vaccinated_2      ...              0          1          0          1
# Vaccinated_3      ...              0          0          1          0
# Dewormed_1        ...              1          1          0          1
# Dewormed_2        ...              0          0          0          0
# Dewormed_3        ...              0          0          1          0
# Sterilized_1      ...              0          0          0          1
# Sterilized_2      ...              1          1          1          0
# Sterilized_3      ...              0          0          0          0
# ...               ...            ...        ...        ...        ...
# Fee_100           ...              0          0          0          0
# Fee_108           ...              0          0          0          0
# Fee_110           ...              0          0          0          0
# Fee_120           ...              0          0          0          0
# Fee_125           ...              0          0          0          0
# Fee_135           ...              0          0          0          0
# Fee_150           ...              0          0          0          0
# Fee_155           ...              0          0          0          0
# Fee_160           ...              0          0          0          0
# Fee_180           ...              0          0          0          0
# Fee_188           ...              0          0          0          0
# Fee_200           ...              0          0          0          0
# Fee_220           ...              0          0          0          0
# Fee_250           ...              0          0          0          0
# Fee_270           ...              0          0          0          0
# Fee_280           ...              0          0          0          0
# Fee_299           ...              0          0          0          0
# Fee_300           ...              0          0          0          0
# Fee_330           ...              0          0          0          0
# Fee_350           ...              0          0          0          0
# Fee_390           ...              0          0          0          0
# Fee_400           ...              0          0          0          0
# Fee_450           ...              0          0          0          0
# Fee_500           ...              0          0          0          0
# Fee_550           ...              0          0          0          0
# Fee_599           ...              0          0          0          0
# Fee_600           ...              0          0          0          0
# Fee_688           ...              0          0          0          0
# Fee_700           ...              0          0          0          0
# Fee_750           ...              0          0          0          0
#
#                      4987       4988       4989       4990       4991  \
# Age                     3         48          3         12          5
# Breed1                307        189        307        266        266
# Breed2                  0        307          0          0          0
# Color1                  2          1          5          7          1
# Color2                  7          0          7          0          4
# Color3                  0          0          0          0          5
# VideoAmt                0          0          0          0          0
# PetID           7ed14130d  3b2b69d20  360215e23  0c612e8df  9b1241ef0
# PhotoAmt                2          4          3          1          2
# Type_1                  1          1          1          0          0
# Type_2                  0          0          0          1          1
# GenderID_1              0          1          0          0          0
# GenderID_2              1          0          1          1          1
# GenderID_3              0          0          0          0          0
# MaturitySize_1          0          0          0          0          0
# MaturitySize_2          1          0          1          1          1
# MaturitySize_3          0          1          0          0          0
# MaturitySize_4          0          0          0          0          0
# FurLength_1             1          1          1          1          0
# FurLength_2             0          0          0          0          1
# FurLength_3             0          0          0          0          0
# Vaccinated_1            0          1          1          1          0
# Vaccinated_2            0          0          0          0          1
# Vaccinated_3            1          0          0          0          0
# Dewormed_1              0          1          1          1          0
# Dewormed_2              0          0          0          0          1
# Dewormed_3              1          0          0          0          0
# Sterilized_1            0          1          0          1          0
# Sterilized_2            1          0          1          0          1
# Sterilized_3            0          0          0          0          0
# ...                   ...        ...        ...        ...        ...
# Fee_100                 0          0          0          0          0
# Fee_108                 0          0          0          0          0
# Fee_110                 0          0          0          0          0
# Fee_120                 0          0          0          0          0
# Fee_125                 0          0          0          0          0
# Fee_135                 0          0          0          0          0
# Fee_150                 0          0          0          0          0
# Fee_155                 0          0          0          0          0
# Fee_160                 0          0          0          0          0
# Fee_180                 0          0          0          0          0
# Fee_188                 0          0          0          0          0
# Fee_200                 0          0          0          0          0
# Fee_220                 0          0          0          0          0
# Fee_250                 0          0          0          0          0
# Fee_270                 0          0          0          0          0
# Fee_280                 0          0          0          0          0
# Fee_299                 0          0          0          0          0
# Fee_300                 0          0          0          0          0
# Fee_330                 0          0          0          0          0
# Fee_350                 0          0          0          0          0
# Fee_390                 0          0          0          0          0
# Fee_400                 0          0          0          0          0
# Fee_450                 0          0          0          0          0
# Fee_500                 0          0          0          0          0
# Fee_550                 0          0          0          0          0
# Fee_599                 0          0          0          0          0
# Fee_600                 0          0          0          0          0
# Fee_688                 0          0          0          0          0
# Fee_700                 0          0          0          0          0
# Fee_750                 0          0          0          0          0
#
#                      4992
# Age                    16
# Breed1                266
# Breed2                  0
# Color1                  1
# Color2                  7
# Color3                  0
# VideoAmt                0
# PetID           ffe7f0b70
# PhotoAmt                5
# Type_1                  0
# Type_2                  1
# GenderID_1              0
# GenderID_2              1
# GenderID_3              0
# MaturitySize_1          0
# MaturitySize_2          0
# MaturitySize_3          1
# MaturitySize_4          0
# FurLength_1             1
# FurLength_2             0
# FurLength_3             0
# Vaccinated_1            0
# Vaccinated_2            1
# Vaccinated_3            0
# Dewormed_1              0
# Dewormed_2              1
# Dewormed_3              0
# Sterilized_1            0
# Sterilized_2            1
# Sterilized_3            0
# ...                   ...
# Fee_100                 0
# Fee_108                 0
# Fee_110                 0
# Fee_120                 0
# Fee_125                 0
# Fee_135                 0
# Fee_150                 0
# Fee_155                 0
# Fee_160                 0
# Fee_180                 0
# Fee_188                 0
# Fee_200                 0
# Fee_220                 0
# Fee_250                 0
# Fee_270                 0
# Fee_280                 0
# Fee_299                 0
# Fee_300                 0
# Fee_330                 0
# Fee_350                 0
# Fee_390                 0
# Fee_400                 0
# Fee_450                 0
# Fee_500                 0
# Fee_550                 0
# Fee_599                 0
# Fee_600                 0
# Fee_688                 0
# Fee_700                 0
# Fee_750                 0
#
# [115 rows x 4993 columns]

# %%
print(df_test_true.columns)
# Out:
# Index(['Age', 'Breed1', 'Breed2', 'Color1', 'Color2', 'Color3', 'VideoAmt',
#        'PetID', 'PhotoAmt', 'Type_1',
#        ...
#        'Fee_390', 'Fee_400', 'Fee_450', 'Fee_500', 'Fee_550', 'Fee_599',
#        'Fee_600', 'Fee_688', 'Fee_700', 'Fee_750'],
#       dtype='object', length=115)

# %%
print(X_columns)
# Out:
# ['Age', 'Breed1', 'Breed2', 'Color1', 'Color2', 'Color3', 'Quantity_1', 'Fee_0', 'Type_1', 'Type_2', 'GenderID_1', 'GenderID_2', 'GenderID_3', 'FurLength_1', 'FurLength_2', 'FurLength_3', 'Vaccinated_1', 'Vaccinated_2', 'Vaccinated_3', 'Dewormed_1', 'Dewormed_2', 'Dewormed_3', 'Sterilized_1', 'Sterilized_2', 'Sterilized_3', 'Health_1', 'Health_2', 'Health_3', 'StateID_41324', 'StateID_41325', 'StateID_41326', 'StateID_41327', 'StateID_41330', 'StateID_41332', 'StateID_41335', 'StateID_41336', 'StateID_41342', 'StateID_41345', 'StateID_41361', 'StateID_41367', 'StateID_41401', 'StateID_41415']

# %%
df_prediction = df_test_true[X_columns]
df_test_true['AdoptionSpeed'] = model.predict(df_prediction)
df_test_true[['PetID', 'AdoptionSpeed']]
# Out:
#           PetID  AdoptionSpeed
# 0     f42161740              2
# 1     0118db3a8              4
# 2     e5164d828              2
# 3     5335bfb38              1
# 4     ff2cf88a0              3
# 5     1d13441b9              2
# 6     7d835cf7c              2
# 7     577d15fea              3
# 8     91736f444              4
# 9     db194aec8              1
# 10    10516f3c6              4
# 11    c3106dcd5              2
# 12    fc3fbbb99              2
# 13    42dd3f3ff              0
# 14    da3be5cb2              3
# 15    4e9a13862              1
# 16    2fbf2cb7c              2
# 17    f45457bdc              2
# 18    aad08c47b              4
# 19    181d40c5e              4
# 20    1a3c44785              4
# 21    6786609aa              4
# 22    1c67c5f4c              1
# 23    bf6a56d33              2
# 24    06fda20a2              2
# 25    b940cf8b8              3
# 26    239c4b696              2
# 27    b67a29908              1
# 28    72f092b4b              2
# 29    7d1d7a4f6              3
# ...         ...            ...
# 4963  ed0185e39              4
# 4964  bf90589d1              4
# 4965  0f796d3f9              1
# 4966  6d53b2d19              0
# 4967  7bc54baef              1
# 4968  87615b2c6              3
# 4969  6f07e7abf              1
# 4970  3bf6cdab0              3
# 4971  00ac364a4              2
# 4972  578b82f50              1
# 4973  f24991ef7              0
# 4974  2e9a64836              1
# 4975  3dab3050c              4
# 4976  4f6029457              2
# 4977  b23e29c89              1
# 4978  0c46298f8              2
# 4979  2f6cde44b              2
# 4980  2f3677597              2
# 4981  256f40704              4
# 4982  653f94080              4
# 4983  878e36da4              2
# 4984  46cf6356e              2
# 4985  ef50eab33              3
# 4986  a40116bf1              4
# 4987  7ed14130d              3
# 4988  3b2b69d20              3
# 4989  360215e23              2
# 4990  0c612e8df              2
# 4991  9b1241ef0              3
# 4992  ffe7f0b70              2
#
# [4993 rows x 2 columns]

# %%
df_test_true[
    ['PetID', 'AdoptionSpeed']].to_csv('submission_classification_modified.csv', index=False)
